# %%
#'https://towardsdatascience.com/how-to-get-market-data-from-the-nyse-in-less-than-3-lines-python-41791212709c'

# !pip3 install pandas-datareader
# !pip3 install DateTime
# Out:
# ...
#      |████████████████████████████████| 109 kB 4.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 52 kB 294 kB/s eta 0:00:011
# ...
#   Using cached zope.interface-5.4.0-cp39-cp39-manylinux2010_x86_64.whl (255 kB)
# ...

# %%
import pandas as pd
from pandas_datareader import data, wb
import datetime

start = pd.to_datetime('2022-07-04')
end = pd.to_datetime('today')

tesla_df = data.DataReader('TSLA', 'yahoo', start , end)
tesla_df
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2022-07-05  699.440002  648.500000  669.000000  699.200012  28193700
# 2022-07-06  703.690002  681.559998  692.340027  695.200012  23951200
# 2022-07-07  736.090027  696.630005  701.760010  733.630005  27310200
# 2022-07-08  764.940002  723.479980  727.000000  752.289978  33343700
# 2022-07-11  759.190002  700.880005  756.309998  703.030029  33080400
# 2022-07-12  719.320007  685.109985  710.539978  699.210022  29310300
# 2022-07-13  726.179993  675.099976  676.500000  711.119995  32651500
# 2022-07-14  715.960022  688.000000  704.690002  714.940002  26069500
# 2022-07-15  730.869873  715.960022  704.690002  718.094971   5079726
#
#              Adj Close
# Date
# 2022-07-05  699.200012
# 2022-07-06  695.200012
# 2022-07-07  733.630005
# 2022-07-08  752.289978
# 2022-07-11  703.030029
# 2022-07-12  699.210022
# 2022-07-13  711.119995
# 2022-07-14  714.940002
# 2022-07-15  718.094971
