# %%
#'https://python.tutorialink.com/need-help-scraping-wsj-markets-data/'

import requests
import pandas as pd
from bs4 import BeautifulSoup


import json
import requests

url = "https://www.wsj.com/market-data/stocks/asia"
params = {
    "id": '{"application":"WSJ","instruments":[{"symbol":"INDEX/HK//HSI","name":"Hong Kong: Hang Seng"},{"symbol":"INDEX/JP//NIK","name":"Japan: Nikkei 225"},{"symbol":"INDEX/CN//SHCOMP","name":"China: Shanghai Composite"},{"symbol":"INDEX/IN//1","name":"India: S&P BSE Sensex"},{"symbol":"INDEX/AU//XJO","name":"Australia: S&P/ASX"},{"symbol":"INDEX/KR//SEU","name":"S. Korea: KOSPI"},{"symbol":"INDEX/US//GDOW","name":"Global Dow"},{"symbol":"FUTURE/US//DJIA FUTURES","name":"DJIA Futures"}]}',
    "type": "mdc_quotes",
}
headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0"
}

data = requests.get(url, params=params, headers=headers).json()

# uncomment to see all data:
# print(json.dumps(data, indent=4))

for instrument in data["data"]["instruments"]:
    print(
        "{:<30} {:<10}".format(
            instrument["formattedName"], instrument["lastPrice"]
        )
    )
df = pd.json_normalize(data["data"]["instruments"])
print(df)
# Out:
# Hong Kong: Hang Seng           20297.72
# Japan: Nikkei 225              26788.47
# China: Shanghai Composite      3228.06
# India: S&P BSE Sensex          53760.78
# Australia: S&P/ASX             6605.6
# S. Korea: KOSPI                2330.98
# Global Dow                     3412.72
# DJIA Futures                   30963
#   country  dailyHigh  dailyLow exchangeIsoCode              formattedName  \
# 0      HK   20656.96  20215.97            XHKG       Hong Kong: Hang Seng
# 1      JP   26857.77  26571.38            XTKS          Japan: Nikkei 225
# 2      CN    3288.92   3228.06            XSHG  China: Shanghai Composite
# 3      IN   53811.37  53361.62            XBOM      India: S&P BSE Sensex
# 4      AU    6622.20   6537.20            XASX         Australia: S&P/ASX
# 5      KR    2337.30   2293.45  Korea Exchange            S. Korea: KOSPI
# 6      US    3425.64   3381.52   S&P Dow Jones                 Global Dow
# 7      US   31103.00  30495.00            XCBT               DJIA Futures
#
#   lastPrice  mantissa                            name priceChange  \
# 0  20297.72         2                 Hang Seng Index     -453.49
# 1  26788.47         2                NIKKEI 225 Index      145.08
# 2   3228.06         2        Shanghai Composite Index      -53.68
# 3  53760.78         2            S&P BSE Sensex Index      344.63
# 4    6605.6         1     S&P/ASX 200 Benchmark Index       -45.0
# 5   2330.98         2           KOSPI Composite Index        8.66
# 6   3412.72         2         Global Dow Realtime USD       29.33
# 7     30963         0  E-Mini Dow Continuous Contract         359
#
#   percentChange            requestSymbol  ticker  \
# 0         -2.19            INDEX/HK//HSI     HSI
# 1          0.54            INDEX/JP//NIK     NIK
# 2         -1.64         INDEX/CN//SHCOMP  SHCOMP
# 3          0.65              INDEX/IN//1       1
# 4         -0.68            INDEX/AU//XJO     XJO
# 5          0.37            INDEX/KR//SEU  180721
# 6          0.87           INDEX/US//GDOW    GDOW
# 7          1.17  FUTURE/US//DJIA FUTURES    YM00
#
#                        timestamp    type  \
# 0      2022-07-15T16:08:36+08:00   Index
# 1      2022-07-15T15:15:02+09:00   Index
# 2      2022-07-15T15:00:34+08:00   Index
# 3      2022-07-15T15:30:49+05:30   Index
# 4      2022-07-15T17:00:30+10:00   Index
# 5      2022-07-15T15:30:40+09:00   Index
# 6      2022-07-15T09:49:34-04:00   Index
# 7  2022-07-15T08:39:37.813-05:00  Future
#
#                                                  url  \
# 0  https://www.wsj.com/market-data/quotes/index/H...
# 1  https://www.wsj.com/market-data/quotes/index/J...
# 2  https://www.wsj.com/market-data/quotes/index/C...
# 3  https://www.wsj.com/market-data/quotes/index/I...
# 4  https://www.wsj.com/market-data/quotes/index/A...
# 5  https://www.wsj.com/market-data/quotes/index/K...
# 6  https://www.wsj.com/market-data/quotes/index/U...
# 7  https://www.wsj.com/market-data/quotes/futures...
#
#              bluegrassChannel.channel bluegrassChannel.type
# 0   /zigman2/quotes/210598030/delayed        DelayedChannel
# 1   /zigman2/quotes/210597971/delayed        DelayedChannel
# 2   /zigman2/quotes/210598127/delayed        DelayedChannel
# 3   /zigman2/quotes/210597966/delayed        DelayedChannel
# 4   /zigman2/quotes/210598100/delayed        DelayedChannel
# 5   /zigman2/quotes/210598069/delayed        DelayedChannel
# 6  /zigman2/quotes/210599024/realtime        DelayedChannel
# 7   /zigman2/quotes/210407078/delayed        DelayedChannel
