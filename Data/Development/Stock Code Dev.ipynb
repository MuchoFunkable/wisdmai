# %%
conda install requests
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
resp = requests.get("https://api.polygon.io/v1/open-close/AAPL/2022-09-30?adjusted=true&apiKey=Eknle1ag4NMz2nqHLzDD_pCzy9kkZdCQ")

# %%
print(resp.text)
# Out:
# {"status":"OK","from":"2022-09-30","symbol":"AAPL","open":141.28,"high":143.1,"low":138,"close":138.2,"volume":1.24910274e+08,"afterHours":137.52,"preMarket":143.59}

# %%
resp2 = requests.get("https://api.polygon.io/v1/open-close/AAPL/2022-10-01?adjusted=true&apiKey=Eknle1ag4NMz2nqHLzDD_pCzy9kkZdCQ")

# %%
print(resp.text)
# Out:
# {"status":"OK","from":"2022-09-30","symbol":"AAPL","open":141.28,"high":143.1,"low":138,"close":138.2,"volume":1.24910274e+08,"afterHours":137.52,"preMarket":143.59}

# %%
agg = requests.get("https://api.polygon.io/v2/aggs/ticker/AAPL/range/1/day/2022-09-22/2022-09-29?adjusted=true&sort=asc&limit=250&apiKey=Eknle1ag4NMz2nqHLzDD_pCzy9kkZdCQ")

# %%
agg.text
# Out:
# '{"ticker":"AAPL","queryCount":6,"resultsCount":6,"adjusted":true,"results":[{"v":8.6652542e+07,"vw":152.5709,"o":152.38,"c":152.74,"h":154.47,"l":150.91,"t":1663819200000,"n":686879},{"v":9.6029909e+07,"vw":150.0222,"o":151.19,"c":150.43,"h":151.47,"l":148.56,"t":1663905600000,"n":766882},{"v":9.3339409e+07,"vw":151.5222,"o":149.66,"c":150.77,"h":153.7701,"l":149.64,"t":1664164800000,"n":747666},{"v":8.4282741e+07,"vw":152.1335,"o":152.74,"c":151.76,"h":154.72,"l":149.945,"t":1664251200000,"n":683776},{"v":1.46661387e+08,"vw":147.5981,"o":147.64,"c":149.84,"h":150.6414,"l":144.84,"t":1664337600000,"n":1142717},{"v":1.28138237e+08,"vw":142.9002,"o":146.1,"c":142.48,"h":146.72,"l":140.68,"t":1664424000000,"n":1067281}],"status":"OK","request_id":"8627cc90e58ee6c198157aa1a5035315","count":6}'

# %%
days = agg.json()["results"]

# %%
days
# Out:
# [{'v': 86652542.0,
#   'vw': 152.5709,
#   'o': 152.38,
#   'c': 152.74,
#   'h': 154.47,
#   'l': 150.91,
#   't': 1663819200000,
#   'n': 686879},
#  {'v': 96029909.0,
#   'vw': 150.0222,
#   'o': 151.19,
#   'c': 150.43,
#   'h': 151.47,
#   'l': 148.56,
#   't': 1663905600000,
#   'n': 766882},
#  {'v': 93339409.0,
#   'vw': 151.5222,
#   'o': 149.66,
#   'c': 150.77,
#   'h': 153.7701,
#   'l': 149.64,
#   't': 1664164800000,
#   'n': 747666},
#  {'v': 84282741.0,
#   'vw': 152.1335,
#   'o': 152.74,
#   'c': 151.76,
#   'h': 154.72,
#   'l': 149.945,
#   't': 1664251200000,
#   'n': 683776},
#  {'v': 146661387.0,
#   'vw': 147.5981,
#   'o': 147.64,
#   'c': 149.84,
#   'h': 150.6414,
#   'l': 144.84,
#   't': 1664337600000,
#   'n': 1142717},
#  {'v': 128138237.0,
#   'vw': 142.9002,
#   'o': 146.1,
#   'c': 142.48,
#   'h': 146.72,
#   'l': 140.68,
#   't': 1664424000000,
#   'n': 1067281}]

# %%
new_arr = []
for i in days:
    new_arr.append(i['o'])
x = ['9/22', '9/23', '9/24', '9/25', '9/26', '9/27']

# %%
conda install matplotlib
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

plt.plot(x,new_arr)
plt.title('AAPL stock from 9/22 to 9/27 by Ryusuke')
plt.xlabel('Days')
plt.ylabel('Open price')
plt.show()

# %%
#automatically searches through news and classifies relavance and sentiment
resp2 = requests.get("https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey=17P39YK2GJ553J0Q")

# %%
print(resp2.text)
# Out:
# {
#     "items": "50",
#     "sentiment_score_definition": "x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish",
#     "relevance_score_definition": "0 < x <= 1, with a higher score indicating higher relevance.",
#     "feed": [
#         {
#             "title": "AirPods Black Friday Sale: Save on Every Model at Amazon",
#             "url": "https://www.thestreet.com/deals/apple-airpods-black-friday-sale-deal",
#             "time_published": "20221115T220100",
#             "authors": [
#                 "Jacob Krol"
#             ],
#             "summary": "Now's the perfect time to get a pair of AirPods for yourself or someone on your holiday shopping list.",
#             "banner_image": "https://www.thestreet.com/.image/t_share/MTkyMTcxNzIyMzc0MzkwOTY1/img_6615.jpg",
#             "source": "The Street",
#             "category_within_source": "n/a",
#             "source_domain": "www.thestreet.com",
#             "topics": [
#                 {
#                     "topic": "Retail & Wholesale",
#                     "relevance_score": "0.5"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.5"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.108179"
#                 }
#             ],
#             "overall_sentiment_score": 0.384455,
#             "overall_sentiment_label": "Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.296582",
#                     "ticker_sentiment_score": "0.491793",
#                     "ticker_sentiment_label": "Bullish"
#                 },
#                 {
#                     "ticker": "AMZN",
#                     "relevance_score": "0.506832",
#                     "ticker_sentiment_score": "0.332288",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 }
#             ]
#         },
#         {
#             "title": "Berkshire Hathaway's Third Quarter 2022 Portfolio Moves",
#             "url": "https://www.forbes.com/sites/bill_stone/2022/11/15/berkshire-hathaways-third-quarter-2022-portfolio-moves/",
#             "time_published": "20221115T174745",
#             "authors": [
#                 "Bill Stone"
#             ],
#             "summary": "Berkshire's $296 billion very concentrated investment portfolio comprises 49 companies, with tech, energy, and financial stocks among the most significant exposure. One holding was eliminated, five decreased, five increased, and Berkshire made three new purchases.",
#             "banner_image": "https://imageio.forbes.com/specials-images/imageserve/6373cf2e0911ddd437dfbf60/0x0.jpg?format=jpg&width=1200",
#             "source": "Forbes",
#             "category_within_source": "Money",
#             "source_domain": "www.forbes.com",
#             "topics": [
#                 {
#                     "topic": "Real Estate & Construction",
#                     "relevance_score": "0.166667"
#                 },
#                 {
#                     "topic": "Retail & Wholesale",
#                     "relevance_score": "0.166667"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.166667"
#                 },
#                 {
#                     "topic": "Manufacturing",
#                     "relevance_score": "0.166667"
#                 },
#                 {
#                     "topic": "Earnings",
#                     "relevance_score": "0.928139"
#                 },
#                 {
#                     "topic": "Energy & Transportation",
#                     "relevance_score": "0.166667"
#                 },
#                 {
#                     "topic": "Finance",
#                     "relevance_score": "0.166667"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.999999"
#                 }
#             ],
#             "overall_sentiment_score": 0.193846,
#             "overall_sentiment_label": "Somewhat-Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "MARUF",
#                     "relevance_score": "0.038101",
#                     "ticker_sentiment_score": "0.035345",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "ITOCF",
#                     "relevance_score": "0.038101",
#                     "ticker_sentiment_score": "0.035345",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CVX",
#                     "relevance_score": "0.2256",
#                     "ticker_sentiment_score": "0.092902",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "GM",
#                     "relevance_score": "0.151539",
#                     "ticker_sentiment_score": "0.182875",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "OXY",
#                     "relevance_score": "0.151539",
#                     "ticker_sentiment_score": "0.048468",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "RH",
#                     "relevance_score": "0.151539",
#                     "ticker_sentiment_score": "0.093499",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "JEF",
#                     "relevance_score": "0.076115",
#                     "ticker_sentiment_score": "0.012215",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "BK",
#                     "relevance_score": "0.076115",
#                     "ticker_sentiment_score": "0.144759",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.113956",
#                     "ticker_sentiment_score": "-0.002275",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "PARA",
#                     "relevance_score": "0.113956",
#                     "ticker_sentiment_score": "0.080869",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "MSBHF",
#                     "relevance_score": "0.038101",
#                     "ticker_sentiment_score": "0.035345",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "MSFT",
#                     "relevance_score": "0.113956",
#                     "ticker_sentiment_score": "0.159001",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "KHC",
#                     "relevance_score": "0.076115",
#                     "ticker_sentiment_score": "-0.002042",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "ATVI",
#                     "relevance_score": "0.188781",
#                     "ticker_sentiment_score": "0.211566",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "LPX",
#                     "relevance_score": "0.076115",
#                     "ticker_sentiment_score": "0.012215",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "MITSF",
#                     "relevance_score": "0.038101",
#                     "ticker_sentiment_score": "0.035345",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "KR",
#                     "relevance_score": "0.113956",
#                     "ticker_sentiment_score": "0.159001",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "BRK-A",
#                     "relevance_score": "0.038101",
#                     "ticker_sentiment_score": "0.035345",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "KO",
#                     "relevance_score": "0.076115",
#                     "ticker_sentiment_score": "-0.002042",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "BAC",
#                     "relevance_score": "0.076115",
#                     "ticker_sentiment_score": "-0.002042",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "STOR",
#                     "relevance_score": "0.076115",
#                     "ticker_sentiment_score": "0.0",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AXP",
#                     "relevance_score": "0.076115",
#                     "ticker_sentiment_score": "-0.002042",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "SSUMF",
#                     "relevance_score": "0.038101",
#                     "ticker_sentiment_score": "0.035345",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "Buffett's Berkshire Buys Shares of Taiwan Semiconductor, Sells Bank Stocks",
#             "url": "https://www.thestreet.com/investing/buffetts-berkshire-buys-shares-of-taiwan-semiconductor-sells-bank-stocks",
#             "time_published": "20221115T172100",
#             "authors": [
#                 "Ellen Chang"
#             ],
#             "summary": "Billionaire Warren Buffett sold some of Berkshire Hathaway's shares of U.S. Bancorp and Bank of New York Mellon.",
#             "banner_image": "https://www.thestreet.com/.image/ar_16:9%2Cc_fill%2Ccs_srgb%2Cfl_progressive%2Cg_faces:center%2Cq_auto:good%2Cw_620/MTkzNzQ3OTE4NDYzNzA2NjA4/thumb-stocks-to-buy-js-111422.jpg",
#             "source": "The Street",
#             "category_within_source": "n/a",
#             "source_domain": "www.thestreet.com",
#             "topics": [
#                 {
#                     "topic": "Finance",
#                     "relevance_score": "0.25"
#                 },
#                 {
#                     "topic": "Energy & Transportation",
#                     "relevance_score": "0.25"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.25"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.996023"
#                 },
#                 {
#                     "topic": "Manufacturing",
#                     "relevance_score": "0.25"
#                 }
#             ],
#             "overall_sentiment_score": 0.39471,
#             "overall_sentiment_label": "Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "MSFT",
#                     "relevance_score": "0.070105",
#                     "ticker_sentiment_score": "0.023502",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "ATVI",
#                     "relevance_score": "0.208166",
#                     "ticker_sentiment_score": "0.186126",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "LPX",
#                     "relevance_score": "0.139669",
#                     "ticker_sentiment_score": "0.285939",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "JEF",
#                     "relevance_score": "0.139669",
#                     "ticker_sentiment_score": "0.316297",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "CVX",
#                     "relevance_score": "0.208166",
#                     "ticker_sentiment_score": "0.344601",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "BRK-A",
#                     "relevance_score": "0.139669",
#                     "ticker_sentiment_score": "0.3681",
#                     "ticker_sentiment_label": "Bullish"
#                 },
#                 {
#                     "ticker": "BK",
#                     "relevance_score": "0.139669",
#                     "ticker_sentiment_score": "0.356107",
#                     "ticker_sentiment_label": "Bullish"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.139669",
#                     "ticker_sentiment_score": "0.307812",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "BAC",
#                     "relevance_score": "0.070105",
#                     "ticker_sentiment_score": "0.253884",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "OXY",
#                     "relevance_score": "0.208166",
#                     "ticker_sentiment_score": "0.344601",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 }
#             ]
#         },
#         {
#             "title": "These Birkenstocks just sold for $218,750 at auction. They belonged to Steve Jobs.",
#             "url": "https://www.marketwatch.com/story/these-steve-jobs-birkenstocks-just-sold-for-218-750-at-auction-11668528903",
#             "time_published": "20221115T161500",
#             "authors": [
#                 "Charles Passy"
#             ],
#             "summary": "There appears to be a growing collectibles market for all things related to the Apple co-founder --- including a 'well used' of sandals that he used to wear ...",
#             "banner_image": "https://images.mktw.net/im-666491/horizontal",
#             "source": "MarketWatch",
#             "category_within_source": "Top Stories",
#             "source_domain": "www.marketwatch.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": -0.002351,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.468029",
#                     "ticker_sentiment_score": "-0.109914",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "What's Going On With Apple Shares - Apple  ( NASDAQ:AAPL ) ",
#             "url": "https://www.benzinga.com/trading-ideas/movers/22/11/29729869/whats-going-on-with-apple-shares",
#             "time_published": "20221115T155116",
#             "authors": [
#                 "Henry Khederian"
#             ],
#             "summary": "Apple Inc AAPL shares are trading higher by 2.84% to $152.49 Tuesday morning. The stock is trading higher in sympathy with the broader market after October PPI data showed a smaller-than-expected rise in wholesale prices. This has helped ease some inflation concerns and has raised hopes of softer ...",
#             "banner_image": "https://cdn.benzinga.com/files/images/story/2022/11/15/ipod-2194567.jpg?width=1200&height=800&fit=crop",
#             "source": "Benzinga",
#             "category_within_source": "Trading",
#             "source_domain": "www.benzinga.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 },
#                 {
#                     "topic": "Economy - Monetary",
#                     "relevance_score": "0.310843"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.266143"
#                 }
#             ],
#             "overall_sentiment_score": 0.12563,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.419153",
#                     "ticker_sentiment_score": "0.30719",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 }
#             ]
#         },
#         {
#             "title": "Over Half of Millennials Own Stocks. Here Are 3 Stock Ideas to Start Your Own Portfolio.",
#             "url": "https://www.fool.com/investing/2022/11/15/over-half-of-millennials-own-stocks-here-are-3/",
#             "time_published": "20221115T153000",
#             "authors": [
#                 "Justin Pope"
#             ],
#             "summary": "This will help you begin your investing journey.",
#             "banner_image": "https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F708375%2Fhappy-investor-rising-stock-graph.jpg&op=resize&w=700",
#             "source": "Motley Fool",
#             "category_within_source": "n/a",
#             "source_domain": "www.fool.com",
#             "topics": [
#                 {
#                     "topic": "Retail & Wholesale",
#                     "relevance_score": "0.5"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.5"
#                 },
#                 {
#                     "topic": "Economy - Monetary",
#                     "relevance_score": "0.451494"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.858979"
#                 },
#                 {
#                     "topic": "Earnings",
#                     "relevance_score": "0.995077"
#                 }
#             ],
#             "overall_sentiment_score": 0.196927,
#             "overall_sentiment_label": "Somewhat-Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.333444",
#                     "ticker_sentiment_score": "0.15485",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "GOOG",
#                     "relevance_score": "0.372139",
#                     "ticker_sentiment_score": "0.114888",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AMZN",
#                     "relevance_score": "0.333444",
#                     "ticker_sentiment_score": "0.154939",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 }
#             ]
#         },
#         {
#             "title": "Why Taiwan Semiconductor Manufacturing Company Shares Are Rising - Taiwan Semiconductor  ( NYSE:TSM ) ",
#             "url": "https://www.benzinga.com/trading-ideas/movers/22/11/29730521/why-taiwan-semiconductor-manufacturing-company-shares-are-rising",
#             "time_published": "20221115T151344",
#             "authors": [
#                 "Henry Khederian"
#             ],
#             "summary": "Taiwan Semiconductor Mfg. Co. Ltd. TSM shares are trading higher by 13.19% to $82.40 during Tuesday's session after Berkshire Hathaway and Tiger Global took stakes in the company.",
#             "banner_image": "https://cdn.benzinga.com/files/images/story/2022/11/15/man-2425121.jpg?width=1200&height=800&fit=crop",
#             "source": "Benzinga",
#             "category_within_source": "Trading",
#             "source_domain": "www.benzinga.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.5"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.161647"
#                 },
#                 {
#                     "topic": "Finance",
#                     "relevance_score": "0.5"
#                 }
#             ],
#             "overall_sentiment_score": 0.056438,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.414559",
#                     "ticker_sentiment_score": "0.15258",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "BRK-A",
#                     "relevance_score": "0.414559",
#                     "ticker_sentiment_score": "0.258956",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 }
#             ]
#         },
#         {
#             "title": "Elon Musk' Lost Millions' Over $8 'Blue Check' Fixation, FTX Hacker Holds $339M In Crypto, Amazon To Cut Workforce Starting This Week: Top Stories Tuesday, Nov. 15 - Apple  ( NASDAQ:AAPL ) , Amazon.com  ( NASDAQ:AMZN ) ",
#             "url": "https://www.benzinga.com/general/biotech/22/11/29729546/elon-musk-lost-millions-over-8-blue-check-fixation-ftx-hacker-holds-339m-in-crypto-amazon-to-cut-",
#             "time_published": "20221115T144127",
#             "authors": [
#                 "Vandana Singh"
#             ],
#             "summary": "Australian health authorities have recommended that a fifth COVID-19 vaccine shot is not necessary, despite average daily cases having been 47% higher last week than the week before.",
#             "banner_image": "https://cdn.benzinga.com/files/images/story/2022/11/15/elon_musk_3018710552.jpg?optimize=medium&dpr=2&auto=webp&width=3840",
#             "source": "Benzinga",
#             "category_within_source": "General",
#             "source_domain": "www.benzinga.com",
#             "topics": [
#                 {
#                     "topic": "Blockchain",
#                     "relevance_score": "0.310843"
#                 },
#                 {
#                     "topic": "Retail & Wholesale",
#                     "relevance_score": "0.2"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.2"
#                 },
#                 {
#                     "topic": "Manufacturing",
#                     "relevance_score": "0.2"
#                 },
#                 {
#                     "topic": "Earnings",
#                     "relevance_score": "0.99676"
#                 },
#                 {
#                     "topic": "IPO",
#                     "relevance_score": "0.310843"
#                 },
#                 {
#                     "topic": "Life Sciences",
#                     "relevance_score": "0.2"
#                 },
#                 {
#                     "topic": "Finance",
#                     "relevance_score": "0.2"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.108179"
#                 }
#             ],
#             "overall_sentiment_score": -0.033655,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "WMT",
#                     "relevance_score": "0.076236",
#                     "ticker_sentiment_score": "-0.018676",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "PPRUF",
#                     "relevance_score": "0.038162",
#                     "ticker_sentiment_score": "-0.208979",
#                     "ticker_sentiment_label": "Somewhat-Bearish"
#                 },
#                 {
#                     "ticker": "ASML",
#                     "relevance_score": "0.189076",
#                     "ticker_sentiment_score": "-0.018669",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "LLY",
#                     "relevance_score": "0.076236",
#                     "ticker_sentiment_score": "0.030037",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "VOD",
#                     "relevance_score": "0.151778",
#                     "ticker_sentiment_score": "0.059828",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "BRK-A",
#                     "relevance_score": "0.038162",
#                     "ticker_sentiment_score": "0.059466",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.076236",
#                     "ticker_sentiment_score": "0.062634",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "GOOG",
#                     "relevance_score": "0.22595",
#                     "ticker_sentiment_score": "0.144449",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "ILMN",
#                     "relevance_score": "0.076236",
#                     "ticker_sentiment_score": "-0.067693",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "HD",
#                     "relevance_score": "0.076236",
#                     "ticker_sentiment_score": "-0.018676",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "TSM",
#                     "relevance_score": "0.076236",
#                     "ticker_sentiment_score": "0.062634",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CRYPTO:BNB",
#                     "relevance_score": "0.038162",
#                     "ticker_sentiment_score": "0.19398",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "CRYPTO:ETH",
#                     "relevance_score": "0.076236",
#                     "ticker_sentiment_score": "0.201245",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "CRYPTO:BRK",
#                     "relevance_score": "0.076236",
#                     "ticker_sentiment_score": "0.062634",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CRYPTO:USDT",
#                     "relevance_score": "0.038162",
#                     "ticker_sentiment_score": "0.19398",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "CRYPTO:MATIC",
#                     "relevance_score": "0.038162",
#                     "ticker_sentiment_score": "0.19398",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "CRYPTO:FTT",
#                     "relevance_score": "0.038162",
#                     "ticker_sentiment_score": "-0.126682",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "Meta Is Cutting Costs Where It Can. Here's What It's Not Giving Up On.",
#             "url": "https://www.fool.com/investing/2022/11/15/where-meta-is-investing-amid-cost-cuts/",
#             "time_published": "20221115T134700",
#             "authors": [
#                 "Adam Levy"
#             ],
#             "summary": "Meta is looking for ways to boost profits without sacrificing its big investments.",
#             "banner_image": "https://g.foolcdn.com/misc-assets/hp-sa-cumulative-growth-chart.png",
#             "source": "Motley Fool",
#             "category_within_source": "n/a",
#             "source_domain": "www.fool.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 },
#                 {
#                     "topic": "Earnings",
#                     "relevance_score": "0.818451"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.929393"
#                 }
#             ],
#             "overall_sentiment_score": 0.292719,
#             "overall_sentiment_label": "Somewhat-Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.067347",
#                     "ticker_sentiment_score": "-0.046172",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "META",
#                     "relevance_score": "0.200134",
#                     "ticker_sentiment_score": "0.365933",
#                     "ticker_sentiment_label": "Bullish"
#                 }
#             ]
#         },
#         {
#             "title": "Emergency SOS via Satellite Available Today on the iPhone 14 Lineup in the US and Canada - Investing News Network",
#             "url": "https://investingnews.com/emergency-sos-via-satellite-available-today-on-the-iphone-14-lineup-in-the-us-and-canada/",
#             "time_published": "20221115T132325",
#             "authors": [],
#             "summary": "Emergency SOS via Satellite Available Today on the iPhone 14 Lineup in the US and Canada Investing News Network ...",
#             "banner_image": null,
#             "source": "Investing News Network",
#             "category_within_source": "n/a",
#             "source_domain": "investingnews.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": 0.165742,
#             "overall_sentiment_label": "Somewhat-Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.028764",
#                     "ticker_sentiment_score": "0.073768",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "Warren Buffett Is Living Off These Five Stocks",
#             "url": "https://www.fool.com/investing/2022/11/15/warren-buffett-is-living-off-these-five-stocks/",
#             "time_published": "20221115T130300",
#             "authors": [
#                 "CPA",
#                 "Mark Roussin"
#             ],
#             "summary": "These 5 dividend stocks pay Warren Buffett over $4 billion in annual dividend income.",
#             "banner_image": "https://g.foolcdn.com/misc-assets/hp-sa-cumulative-growth-chart.png",
#             "source": "Motley Fool",
#             "category_within_source": "n/a",
#             "source_domain": "www.fool.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": 0.030685,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.798255",
#                     "ticker_sentiment_score": "-0.163359",
#                     "ticker_sentiment_label": "Somewhat-Bearish"
#                 }
#             ]
#         },
#         {
#             "title": "Steve Jobs' Personal NFT Sandals Sold For Over $200,000 At Auction - Matic Network  ( MATIC/USD ) ",
#             "url": "https://www.benzinga.com/markets/cryptocurrency/22/11/29720907/steve-jobs-personal-nft-sandals-sold-for-over-200-000-at-auction",
#             "time_published": "20221115T123509",
#             "authors": [
#                 "Mehab Qureshi"
#             ],
#             "summary": "A pair of Birkenstock sandals worn by Apple Inc. APPL co-founder Steve Jobs throughout his life has been auctioned off for $218,750. Included in the deal was an NFT featuring Steve Jobs' sandals, minted on Polygon MATIC/USD blockchain. What Happened: Julien's Auctions organized the auction from ...",
#             "banner_image": "https://cdn.benzinga.com/files/images/story/2022/11/15/shutterstock_357189857.jpg?width=1200&height=800&fit=crop",
#             "source": "Benzinga",
#             "category_within_source": "Markets",
#             "source_domain": "www.benzinga.com",
#             "topics": [
#                 {
#                     "topic": "Blockchain",
#                     "relevance_score": "0.682689"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.108179"
#                 }
#             ],
#             "overall_sentiment_score": -0.039769,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.197413",
#                     "ticker_sentiment_score": "-0.088683",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CRYPTO:MATIC",
#                     "relevance_score": "0.382925",
#                     "ticker_sentiment_score": "-0.096944",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CRYPTO:DOGE",
#                     "relevance_score": "0.197413",
#                     "ticker_sentiment_score": "-0.028433",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "2 Monster Stocks to Buy for 2023 That Are Practically Minting Money",
#             "url": "https://www.fool.com/investing/2022/11/15/2-monster-stocks-to-buy-for-2023-that-are-practica/",
#             "time_published": "20221115T120000",
#             "authors": [
#                 "Dani Cook"
#             ],
#             "summary": "AMD and Apple have recently defied market declines and could provide significant gains in 2023.",
#             "banner_image": "https://g.foolcdn.com/misc-assets/hp-sa-cumulative-growth-chart.png",
#             "source": "Motley Fool",
#             "category_within_source": "n/a",
#             "source_domain": "www.fool.com",
#             "topics": [
#                 {
#                     "topic": "Earnings",
#                     "relevance_score": "0.214378"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.5"
#                 },
#                 {
#                     "topic": "Economy - Monetary",
#                     "relevance_score": "0.158519"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.962106"
#                 },
#                 {
#                     "topic": "Manufacturing",
#                     "relevance_score": "0.5"
#                 }
#             ],
#             "overall_sentiment_score": 0.203599,
#             "overall_sentiment_label": "Somewhat-Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.561452",
#                     "ticker_sentiment_score": "0.185397",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "AMD",
#                     "relevance_score": "0.327366",
#                     "ticker_sentiment_score": "0.137164",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "GOOG",
#                     "relevance_score": "0.056143",
#                     "ticker_sentiment_score": "0.006001",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "Warren Buffett's Berkshire Hathaway buys stock worth $4.1 bn in TSMC",
#             "url": "https://www.business-standard.com/article/international/warren-buffett-s-berkshire-hathaway-buys-stock-worth-4-1-bn-in-tsmc-122111501582_1.html",
#             "time_published": "20221115T114600",
#             "authors": [
#                 "Reuters"
#             ],
#             "summary": "TSMC's other foreign investors include U.S. asset managers BlackRock Inc and Vanguard Group Inc, and Singapore sovereign wealth fund ...",
#             "banner_image": "https://bsmedia.business-standard.com/_media/bs/img/article/2021-05/24/full/1621835648-7368.jpg?im=Resize,width=640",
#             "source": "Business Standard",
#             "category_within_source": "Top Stories",
#             "source_domain": "www.business-standard.com",
#             "topics": [
#                 {
#                     "topic": "Real Estate & Construction",
#                     "relevance_score": "0.166667"
#                 },
#                 {
#                     "topic": "Retail & Wholesale",
#                     "relevance_score": "0.166667"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.166667"
#                 },
#                 {
#                     "topic": "Manufacturing",
#                     "relevance_score": "0.166667"
#                 },
#                 {
#                     "topic": "Earnings",
#                     "relevance_score": "0.158519"
#                 },
#                 {
#                     "topic": "Energy & Transportation",
#                     "relevance_score": "0.166667"
#                 },
#                 {
#                     "topic": "Finance",
#                     "relevance_score": "0.166667"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.316726"
#                 }
#             ],
#             "overall_sentiment_score": 0.172795,
#             "overall_sentiment_label": "Somewhat-Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "ATVI",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "0.168377",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "LPX",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "0.05733",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "JEF",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "0.05733",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CVX",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "0.0",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "KR",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "0.168377",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "BRK-A",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "0.070425",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "BK",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "0.168377",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "BLK",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "0.219038",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "-0.064643",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "NVDA",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "-0.064643",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "GM",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "0.168377",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "BYDDF",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "0.0",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "TSM",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "0.070425",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "STOR",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "0.05733",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "OXY",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "0.0",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "RH",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "0.0",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "PARA",
#                     "relevance_score": "0.072435",
#                     "ticker_sentiment_score": "0.0",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "Should iShares S&P 100 ETF  ( OEF )  Be on Your Investing Radar?",
#             "url": "https://www.zacks.com/stock/news/2018219/should-ishares-sp-100-etf-oef-be-on-your-investing-radar",
#             "time_published": "20221115T112009",
#             "authors": [
#                 "Zacks Investment Research"
#             ],
#             "summary": "Style Box ETF report for ...",
#             "banner_image": "https://staticx-tuner.zacks.com/images/default_article_images/default73.jpg",
#             "source": "Zacks Commentary",
#             "category_within_source": "n/a",
#             "source_domain": "www.zacks.com",
#             "topics": [
#                 {
#                     "topic": "Retail & Wholesale",
#                     "relevance_score": "0.333333"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.333333"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "1.0"
#                 },
#                 {
#                     "topic": "Finance",
#                     "relevance_score": "0.333333"
#                 }
#             ],
#             "overall_sentiment_score": 0.138465,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "BLK",
#                     "relevance_score": "0.065327",
#                     "ticker_sentiment_score": "0.050043",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "MSFT",
#                     "relevance_score": "0.130217",
#                     "ticker_sentiment_score": "0.064442",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.130217",
#                     "ticker_sentiment_score": "0.064442",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AMZN",
#                     "relevance_score": "0.130217",
#                     "ticker_sentiment_score": "0.064442",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "China consumer, factory activity down as virus controls rise",
#             "url": "https://apnews.com/article/business-china-beijing-economy-consumer-spending-1548098201d709604ef55db73c219b8c",
#             "time_published": "20221115T084746",
#             "authors": [],
#             "summary": "A woman works in a textile factory in Human in eastern China's Shandong Province, Nov. 1, 2022. Chinese consumer spending contracted in October and factory activity weakened as anti-virus controls following a rise in infections weighed on the economy. ( Chinatopix via AP )",
#             "banner_image": "https://storage.googleapis.com/afs-prod/media/8fcb4defd0cb4324a315739bf4ec16b8/3000.jpeg",
#             "source": "Associated Press",
#             "category_within_source": "Business",
#             "source_domain": "apnews.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 },
#                 {
#                     "topic": "Economy - Monetary",
#                     "relevance_score": "0.451494"
#                 }
#             ],
#             "overall_sentiment_score": -0.212044,
#             "overall_sentiment_label": "Somewhat-Bearish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.082963",
#                     "ticker_sentiment_score": "-0.215435",
#                     "ticker_sentiment_label": "Somewhat-Bearish"
#                 }
#             ]
#         },
#         {
#             "title": "Warren Buffett's company buys $4 billion stake in Taiwanese chip giant TSMC | Business",
#             "url": "https://www.cnn.com/2022/11/15/investing/tsmc-shares-berkshire-hathaway-stake-hnk-intl/index.html",
#             "time_published": "20221115T064300",
#             "authors": [
#                 "Diksha Madhok"
#             ],
#             "summary": "Warren Buffett's company buys $4 billion stake in Taiwanese chip giant ...",
#             "banner_image": "https://media.cnn.com/api/v1/images/stellar/prod/221115013140-tsmc-headquarters-111522.jpg?c=16x9&q=w_800,c_fill",
#             "source": "CNN",
#             "category_within_source": "Markets",
#             "source_domain": "www.cnn.com",
#             "topics": [
#                 {
#                     "topic": "Finance",
#                     "relevance_score": "0.333333"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.333333"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.360215"
#                 },
#                 {
# ...
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "FOREX:USD",
#                     "relevance_score": "0.00661",
#                     "ticker_sentiment_score": "0.132698",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "How these 22 tech stocks stand out from the pack this earnings season",
#             "url": "https://www.marketwatch.com/story/how-these-22-tech-stocks-stand-out-from-the-pack-this-earnings-season-11668439971",
#             "time_published": "20221114T153200",
#             "authors": [
#                 "Philip van Doorn"
#             ],
#             "summary": "Companies including Electronic Arts, ON Semiconductor and Fiserv pulled off a difficult feat in a down cycle --- improving sales and profit margins.",
#             "banner_image": "https://images.mktw.net/im-665507/social",
#             "source": "MarketWatch",
#             "category_within_source": "Top Stories",
#             "source_domain": "www.marketwatch.com",
#             "topics": [
#                 {
#                     "topic": "Retail & Wholesale",
#                     "relevance_score": "0.333333"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.333333"
#                 },
#                 {
#                     "topic": "Manufacturing",
#                     "relevance_score": "0.333333"
#                 },
#                 {
#                     "topic": "Earnings",
#                     "relevance_score": "0.495866"
#                 }
#             ],
#             "overall_sentiment_score": 0.143372,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "MSFT",
#                     "relevance_score": "0.200134",
#                     "ticker_sentiment_score": "0.00777",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "NFLX",
#                     "relevance_score": "0.200134",
#                     "ticker_sentiment_score": "0.00777",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "TSLA",
#                     "relevance_score": "0.327366",
#                     "ticker_sentiment_score": "0.095319",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "META",
#                     "relevance_score": "0.200134",
#                     "ticker_sentiment_score": "0.012507",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.200134",
#                     "ticker_sentiment_score": "0.00777",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "GOOG",
#                     "relevance_score": "0.134214",
#                     "ticker_sentiment_score": "0.009604",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AMZN",
#                     "relevance_score": "0.200134",
#                     "ticker_sentiment_score": "0.02202",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "Apple Stock Slides As CEO Tim Cook Says iPhone Maker Has Slowed Down Hiring",
#             "url": "https://www.thestreet.com/markets/apple-stock-slides-as-ceo-tim-cook-says-group-has-slowed-hiring",
#             "time_published": "20221114T152900",
#             "authors": [
#                 "Martin Baccardax"
#             ],
#             "summary": "\"We're being very deliberate on our hiring ... that means we're continuing to hire, but not everywhere in the company,\" said Apple CEO Tim Cook.",
#             "banner_image": "https://www.thestreet.com/.image/ar_16:9%2Cc_fill%2Ccs_srgb%2Cfl_progressive%2Cg_faces:center%2Cq_auto:good%2Cw_620/MTkzNjc3NTQ4Mzc3MzUxNjE5/trader-lead-js-111122.jpg",
#             "source": "The Street",
#             "category_within_source": "n/a",
#             "source_domain": "www.thestreet.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.360215"
#                 }
#             ],
#             "overall_sentiment_score": 0.093212,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "MSFT",
#                     "relevance_score": "0.16117",
#                     "ticker_sentiment_score": "0.176033",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "META",
#                     "relevance_score": "0.239698",
#                     "ticker_sentiment_score": "-0.003759",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "GOOG",
#                     "relevance_score": "0.081001",
#                     "ticker_sentiment_score": "0.13291",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.523451",
#                     "ticker_sentiment_score": "-0.098637",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "Apple CEO Tim Cook says company is still hiring but being 'very deliberate'",
#             "url": "https://www.marketwatch.com/story/apple-ceo-tim-cook-says-company-is-still-hiring-but-being-very-deliberate-11668439707",
#             "time_published": "20221114T152800",
#             "authors": [
#                 "Emily Bary"
#             ],
#             "summary": "Amid a backdrop of hiring freezes and layoffs across the tech industry, Apple's Tim Cook said the smartphone giant was bringing on new employees in some roles but taking a more restrained approach to overall hiring.",
#             "banner_image": "https://images.mktw.net/im-619064/social",
#             "source": "MarketWatch",
#             "category_within_source": "Top Stories",
#             "source_domain": "www.marketwatch.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.5"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.360215"
#                 },
#                 {
#                     "topic": "Manufacturing",
#                     "relevance_score": "0.5"
#                 }
#             ],
#             "overall_sentiment_score": 0.044429,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "SNAP",
#                     "relevance_score": "0.244109",
#                     "ticker_sentiment_score": "0.05346",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.56296",
#                     "ticker_sentiment_score": "0.07084",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "META",
#                     "relevance_score": "0.359014",
#                     "ticker_sentiment_score": "0.072612",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "SHOP",
#                     "relevance_score": "0.244109",
#                     "ticker_sentiment_score": "0.05346",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "PTON",
#                     "relevance_score": "0.244109",
#                     "ticker_sentiment_score": "0.05346",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "Less Than $1: This Apple iCloud Class Action Settlement Payout May Afford Users Just A Donut - Apple  ( NASDAQ:AAPL ) ",
#             "url": "https://www.benzinga.com/news/22/11/29694449/less-than-1-this-apple-icloud-class-action-settlement-payout-may-afford-users-just-a-donut",
#             "time_published": "20221114T152227",
#             "authors": [
#                 "Ananya Gairola"
#             ],
#             "summary": "Apple Inc. AAPL iCloud subscribers in the U.S. have started receiving notifications that they would be compensated as part of a $14.8-million class action settlement - but the users will only get less than a dollar.",
#             "banner_image": "https://cdn.benzinga.com/files/images/story/2022/11/14/shutterstock_1421830097.jpg?width=1200&height=800&fit=crop",
#             "source": "Benzinga",
#             "category_within_source": "News",
#             "source_domain": "www.benzinga.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": -0.011826,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "MSFT",
#                     "relevance_score": "0.290607",
#                     "ticker_sentiment_score": "-0.133285",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.648497",
#                     "ticker_sentiment_score": "0.018202",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "GOOG",
#                     "relevance_score": "0.290607",
#                     "ticker_sentiment_score": "-0.133285",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "DTST",
#                     "relevance_score": "0.147818",
#                     "ticker_sentiment_score": "0.040432",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "Apple Sued For Tracking Users' 'Intimate' Data Even When iPhone Analytics Is Disabled - Apple  ( NASDAQ:AAPL ) ",
#             "url": "https://www.benzinga.com/news/22/11/29693988/apple-sued-for-tracking-users-intimate-data-even-when-iphone-analytics-is-disabled",
#             "time_published": "20221114T131133",
#             "authors": [
#                 "Ananya Gairola"
#             ],
#             "summary": "Apple Inc. AAPL is facing a new lawsuit that says the Cupertino-based tech giant is violating users' privacy rights and monetizing their data without permission.",
#             "banner_image": "https://cdn.benzinga.com/files/images/story/2022/11/14/shutterstock_1883088670.jpg?width=1200&height=800&fit=crop",
#             "source": "Benzinga",
#             "category_within_source": "News",
#             "source_domain": "www.benzinga.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": 0.026702,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.906257",
#                     "ticker_sentiment_score": "-0.017029",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "Best Leveraged ETFs of Last Week",
#             "url": "https://www.zacks.com/stock/news/2017688/best-leveraged-etfs-of-last-week",
#             "time_published": "20221114T130000",
#             "authors": [
#                 "Zacks Investment Research"
#             ],
#             "summary": "Wall Street was upbeat last week. The S&P 500 logged best week since June, per CNBC.",
#             "banner_image": "https://staticx-tuner.zacks.com/images/default_article_images/default176.jpg",
#             "source": "Zacks Commentary",
#             "category_within_source": "n/a",
#             "source_domain": "www.zacks.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 },
#                 {
#                     "topic": "Economy - Monetary",
#                     "relevance_score": "0.972193"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.94762"
#                 }
#             ],
#             "overall_sentiment_score": 0.256941,
#             "overall_sentiment_label": "Somewhat-Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.192694",
#                     "ticker_sentiment_score": "0.383528",
#                     "ticker_sentiment_label": "Bullish"
#                 }
#             ]
#         },
#         {
#             "title": "US Stocks: Futures decline on cautious Fed tone on inflation | The Financial Express",
#             "url": "https://www.financialexpress.com/market/us-stocks-futures-decline-on-cautious-fed-tone-on-inflation/2812280/",
#             "time_published": "20221114T123219",
#             "authors": [],
#             "summary": "US Stocks: Futures decline on cautious Fed tone on inflation The Financial Express ...",
#             "banner_image": "https://www.financialexpress.com/wp-content/uploads/2022/11/usstocks-1.jpg",
#             "source": "The Financial Express",
#             "category_within_source": "MarketsGoogleRSS",
#             "source_domain": "www.financialexpress.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.5"
#                 },
#                 {
#                     "topic": "Economy - Monetary",
#                     "relevance_score": "0.938238"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.684621"
#                 },
#                 {
#                     "topic": "Manufacturing",
#                     "relevance_score": "0.5"
#                 }
#             ],
#             "overall_sentiment_score": 0.033534,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.114137",
#                     "ticker_sentiment_score": "0.232018",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "HRGLF",
#                     "relevance_score": "0.114137",
#                     "ticker_sentiment_score": "0.01816",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "TSLA",
#                     "relevance_score": "0.114137",
#                     "ticker_sentiment_score": "0.065313",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "INTC",
#                     "relevance_score": "0.114137",
#                     "ticker_sentiment_score": "0.232018",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 }
#             ]
#         }
#     ]
# }

# %%
resp3 = requests.get("https://financialmodelingprep.com/api/v3/stock_market/gainers?apikey=37fe2a7ee9f6099cf3a062fae59990bd")

# %%
print(len(resp3.text))
# Out:
# 3977

# %%
gainers = resp3.json()
gainers
# Out:
# [{'symbol': 'XGN',
#   'name': 'Exagen Inc.',
#   'change': 0.89,
#   'price': 2.99,
#   'changesPercentage': 42.38096},
#  {'symbol': 'LMAOU',
#   'name': 'LMF Acquisition Opportunities, Inc.',
#   'change': 3.66,
#   'price': 12.46,
#   'changesPercentage': 41.5909},
#  {'symbol': 'QRTEB',
#   'name': 'Qurate Retail, Inc.',
#   'change': 2.0883,
#   'price': 7.1383,
#   'changesPercentage': 41.35247},
#  {'symbol': 'FDMT',
#   'name': '4D Molecular Therapeutics, Inc.',
#   'change': 5.2,
#   'price': 18.69,
#   'changesPercentage': 38.547077},
#  {'symbol': 'HUYA',
#   'name': 'HUYA Inc.',
#   'change': 0.88,
#   'price': 3.18,
#   'changesPercentage': 38.260876},
#  {'symbol': 'SE',
#   'name': 'Sea Limited',
#   'change': 16.51,
#   'price': 62.31,
#   'changesPercentage': 36.04804},
#  {'symbol': 'TRUE',
#   'name': 'TrueCar, Inc.',
#   'change': 0.64,
#   'price': 2.59,
#   'changesPercentage': 32.820503},
#  {'symbol': 'GRFX',
#   'name': 'Graphex Group Limited',
#   'change': 0.34,
#   'price': 1.38,
#   'changesPercentage': 32.692314},
#  {'symbol': 'XL',
#   'name': 'XL Fleet Corp.',
#   'change': 0.2692,
#   'price': 1.14,
#   'changesPercentage': 30.9141},
#  {'symbol': 'TME',
#   'name': 'Tencent Music Entertainment Group',
#   'change': 1.36,
#   'price': 5.81,
#   'changesPercentage': 30.561802},
#  {'symbol': 'SUNL',
#   'name': 'Sunlight Financial Holdings Inc.',
#   'change': 0.39,
#   'price': 1.69,
#   'changesPercentage': 30.00001},
#  {'symbol': 'WHLRP',
#   'name': 'Wheeler Real Estate Investment Trust, Inc.',
#   'change': 0.66,
#   'price': 3.08,
#   'changesPercentage': 27.272718},
#  {'symbol': 'BILI',
#   'name': 'Bilibili Inc.',
#   'change': 3.4,
#   'price': 16.28,
#   'changesPercentage': 26.39752},
#  {'symbol': 'GOTU',
#   'name': 'Gaotu Techedu Inc.',
#   'change': 0.2312,
#   'price': 1.12,
#   'changesPercentage': 26.0126},
#  {'symbol': 'DAO',
#   'name': 'Youdao, Inc.',
#   'change': 0.86,
#   'price': 4.24,
#   'changesPercentage': 25.443777},
#  {'symbol': 'DRIO',
#   'name': 'DarioHealth Corp.',
#   'change': 0.99,
#   'price': 4.91,
#   'changesPercentage': 25.255096},
#  {'symbol': 'ZH',
#   'name': 'Zhihu Inc.',
#   'change': 0.25,
#   'price': 1.27,
#   'changesPercentage': 24.509804},
#  {'symbol': 'LU',
#   'name': 'Lufax Holding Ltd',
#   'change': 0.45,
#   'price': 2.34,
#   'changesPercentage': 23.80952},
#  {'symbol': 'EH',
#   'name': 'EHang Holdings Limited',
#   'change': 0.94,
#   'price': 4.89,
#   'changesPercentage': 23.797462},
#  {'symbol': 'PDSB',
#   'name': 'PDS Biotechnology Corporation',
#   'change': 1.62,
#   'price': 8.68,
#   'changesPercentage': 22.94618},
#  {'symbol': 'DADA',
#   'name': 'Dada Nexus Limited',
#   'change': 0.93,
#   'price': 5.03,
#   'changesPercentage': 22.682936},
#  {'symbol': 'GDS',
#   'name': 'GDS Holdings Limited',
#   'change': 3.07,
#   'price': 16.62,
#   'changesPercentage': 22.656832},
#  {'symbol': 'UXIN',
#   'name': 'Uxin Limited',
#   'change': 0.61,
#   'price': 3.33,
#   'changesPercentage': 22.426466},
#  {'symbol': 'DOYU',
#   'name': 'DouYu International Holdings Limited',
#   'change': 0.25,
#   'price': 1.37,
#   'changesPercentage': 22.321428},
#  {'symbol': 'BCAN',
#   'name': 'BYND Cannasoft Enterprises Inc.',
#   'change': 0.54,
#   'price': 3.0,
#   'changesPercentage': 21.951218},
#  {'symbol': 'SHLS',
#   'name': 'Shoals Technologies Group, Inc.',
#   'change': 4.93,
#   'price': 27.4,
#   'changesPercentage': 21.940367},
#  {'symbol': 'AZTA',
#   'name': 'Azenta, Inc.',
#   'change': 10.17,
#   'price': 56.75,
#   'changesPercentage': 21.8334},
#  {'symbol': 'NRGV',
#   'name': 'Energy Vault Holdings, Inc.',
#   'change': 0.7,
#   'price': 3.94,
#   'changesPercentage': 21.60494},
#  {'symbol': 'HTOO',
#   'name': 'Fusion Fuel Green PLC',
#   'change': 0.63,
#   'price': 3.58,
#   'changesPercentage': 21.355927},
#  {'symbol': 'TDUP',
#   'name': 'ThredUp Inc.',
#   'change': 0.2111,
#   'price': 1.2,
#   'changesPercentage': 21.346954}]

# %%
resp4 = requests.get("https://financialmodelingprep.com/api/v3/stock_market/losers?apikey=37fe2a7ee9f6099cf3a062fae59990bd")

# %%
losers = resp4.json()
losers
# Out:
# [{'symbol': 'SRZN',
#   'name': 'Surrozen, Inc.',
#   'change': -0.54,
#   'price': 1.25,
#   'changesPercentage': -30.167597},
#  {'symbol': 'POWW',
#   'name': 'AMMO, Inc.',
#   'change': -0.81,
#   'price': 2.33,
#   'changesPercentage': -25.796185},
#  {'symbol': 'BKYI',
#   'name': 'BIO-key International, Inc.',
#   'change': -0.41,
#   'price': 1.19,
#   'changesPercentage': -25.624996},
#  {'symbol': 'TUSK',
#   'name': 'Mammoth Energy Services, Inc.',
#   'change': -1.9,
#   'price': 6.09,
#   'changesPercentage': -23.77972},
#  {'symbol': 'CWCO',
#   'name': 'Consolidated Water Co. Ltd.',
#   'change': -3.81,
#   'price': 13.7,
#   'changesPercentage': -21.758997},
#  {'symbol': 'RVPH',
#   'name': 'Reviva Pharmaceuticals Holdings, Inc.',
#   'change': -1.02,
#   'price': 3.97,
#   'changesPercentage': -20.440878},
#  {'symbol': 'TWST',
#   'name': 'Twist Bioscience Corporation',
#   'change': -7.57,
#   'price': 30.43,
#   'changesPercentage': -19.921053},
#  {'symbol': 'RBT',
#   'name': 'Rubicon Technologies, Inc.',
#   'change': -0.5,
#   'price': 2.1,
#   'changesPercentage': -19.2308},
#  {'symbol': 'VS',
#   'name': 'Versus Systems Inc.',
#   'change': -0.51,
#   'price': 2.15,
#   'changesPercentage': -19.172932},
#  {'symbol': 'TFFP',
#   'name': 'TFF Pharmaceuticals, Inc.',
#   'change': -0.28,
#   'price': 1.2,
#   'changesPercentage': -18.918917},
#  {'symbol': 'AXDX',
#   'name': 'Accelerate Diagnostics, Inc.',
#   'change': -0.28,
#   'price': 1.22,
#   'changesPercentage': -18.666666},
#  {'symbol': 'ISIG',
#   'name': 'Insignia Systems, Inc.',
#   'change': -1.45,
#   'price': 6.89,
#   'changesPercentage': -17.386093},
#  {'symbol': 'SI',
#   'name': 'Silvergate Capital Corporation',
#   'change': -6.13,
#   'price': 29.36,
#   'changesPercentage': -17.2725},
#  {'symbol': 'QRHC',
#   'name': 'Quest Resource Holding Corporation',
#   'change': -1.41,
#   'price': 6.97,
#   'changesPercentage': -16.825779},
#  {'symbol': 'HSCS',
#   'name': 'Heart Test Laboratories, Inc.',
#   'change': -0.32,
#   'price': 1.65,
#   'changesPercentage': -16.243658},
#  {'symbol': 'GETY',
#   'name': 'Getty Images Holdings, Inc.',
#   'change': -1.11,
#   'price': 5.86,
#   'changesPercentage': -15.9254},
#  {'symbol': 'MASS',
#   'name': '908 Devices Inc.',
#   'change': -1.98,
#   'price': 10.5,
#   'changesPercentage': -15.865381},
#  {'symbol': 'QTEK',
#   'name': 'QualTek Services Inc.',
#   'change': -0.24,
#   'price': 1.3,
#   'changesPercentage': -15.584416},
#  {'symbol': 'PRTC',
#   'name': 'PureTech Health plc',
#   'change': -5.03,
#   'price': 27.37,
#   'changesPercentage': -15.524693},
#  {'symbol': 'BMTX',
#   'name': 'BM Technologies, Inc.',
#   'change': -1.26,
#   'price': 6.93,
#   'changesPercentage': -15.3846},
#  {'symbol': 'SABS',
#   'name': 'SAB Biotherapeutics, Inc.',
#   'change': -0.19,
#   'price': 1.06,
#   'changesPercentage': -15.200004},
#  {'symbol': 'TBLT',
#   'name': 'ToughBuilt Industries, Inc.',
#   'change': -0.57,
#   'price': 3.22,
#   'changesPercentage': -15.039577},
#  {'symbol': 'LUMO',
#   'name': 'Lumos Pharma, Inc.',
#   'change': -0.87,
#   'price': 4.95,
#   'changesPercentage': -14.948459},
#  {'symbol': 'TMCI',
#   'name': 'Treace Medical Concepts, Inc.',
#   'change': -3.57,
#   'price': 20.54,
#   'changesPercentage': -14.807132},
#  {'symbol': 'ISUN',
#   'name': 'iSun, Inc.',
#   'change': -0.34,
#   'price': 2.0,
#   'changesPercentage': -14.529911},
#  {'symbol': 'CDRE',
#   'name': 'Cadre Holdings, Inc.',
#   'change': -4.18,
#   'price': 25.3,
#   'changesPercentage': -14.179106},
#  {'symbol': 'CALA',
#   'name': 'Calithera Biosciences, Inc.',
#   'change': -0.39,
#   'price': 2.38,
#   'changesPercentage': -14.079417},
#  {'symbol': 'IDN',
#   'name': 'Intellicheck, Inc.',
#   'change': -0.34,
#   'price': 2.11,
#   'changesPercentage': -13.877557},
#  {'symbol': 'AGS',
#   'name': 'PlayAGS, Inc.',
#   'change': -0.85,
#   'price': 5.5,
#   'changesPercentage': -13.385825},
#  {'symbol': 'IMGN',
#   'name': 'ImmunoGen, Inc.',
#   'change': -0.75,
#   'price': 5.01,
#   'changesPercentage': -13.020833}]

# %%
stockset = {}
default_big = ['MSFT', 'AAPL', 'WMT', 'TSLA', 'AMZN', 'DIS', 'PFE']

# %%
tengainers = gainers[:10]
for s in tengainers:
    mc = requests.get("https://financialmodelingprep.com/api/v3/market-capitalization/" + str(s['symbol']) + "?apikey=37fe2a7ee9f6099cf3a062fae59990bd")
    mcap = mc.json()
    print(mcap)
    print(mcap[0]['marketCap'])
    stockset[str(s['symbol'])] = int(mcap[0]['marketCap'])
# Out:
# [{'symbol': 'XGN', 'date': '2022-11-14', 'marketCap': 34146840}]
# 34146840
# [{'symbol': 'LMAOU', 'date': '2022-11-14', 'marketCap': 0.0}]
# 0.0
# [{'symbol': 'QRTEB', 'date': '2022-11-14', 'marketCap': 788782720}]
# 788782720
# [{'symbol': 'FDMT', 'date': '2022-11-14', 'marketCap': 436973472}]
# 436973472
# [{'symbol': 'HUYA', 'date': '2022-11-14', 'marketCap': 550206016}]
# 550206016
# [{'symbol': 'SE', 'date': '2022-11-14', 'marketCap': 25727598592}]
# 25727598592
# [{'symbol': 'TRUE', 'date': '2022-11-14', 'marketCap': 171820752}]
# 171820752
# [{'symbol': 'GRFX', 'date': '2022-11-14', 'marketCap': 37710712}]
# 37710712
# [{'symbol': 'XL', 'date': '2022-11-11', 'marketCap': 164297936}]
# 164297936
# [{'symbol': 'TME', 'date': '2022-11-14', 'marketCap': 7543105536}]
# 7543105536

# %%
tenlosers = losers[:10]
for s in tenlosers:
    mc = requests.get("https://financialmodelingprep.com/api/v3/market-capitalization/" + str(s['symbol']) + "?apikey=37fe2a7ee9f6099cf3a062fae59990bd")
    mcap = mc.json()
    stockset[s['symbol']] = int(mcap[0]['marketCap'])

# %%
print(stockset)
# Out:
# {'XGN': 34146840, 'LMAOU': 0, 'QRTEB': 788782720, 'FDMT': 436973472, 'HUYA': 550206016, 'SE': 25727598592, 'TRUE': 171820752, 'GRFX': 37710712, 'XL': 164297936, 'TME': 7543105536, 'SRZN': 62869988, 'POWW': 367257568, 'BKYI': 13183544, 'TUSK': 378025280, 'CWCO': 267752416, 'RVPH': 102010064, 'TWST': 2141812992, 'RBT': 418743008, 'VS': 4488278, 'TFFP': 37707144, 'MSFT': 1800627290112, 'AAPL': 2358852976640, 'WMT': 375623680000, 'TSLA': 602972356608, 'AMZN': 1004765446144, 'DIS': 167912669184, 'PFE': 276399390720}

# %%
for d in default_big:
    mc = requests.get("https://financialmodelingprep.com/api/v3/market-capitalization/" + str(d) + "?apikey=37fe2a7ee9f6099cf3a062fae59990bd")
    mcap = mc.json()
    print(mcap[0]['marketCap'])
    stockset[d] = int(mcap[0]['marketCap'])
# Out:
# 1800627290112
# 2358852976640
# 375623680000
# 602972356608
# 1004765446144
# 167912669184
# 276399390720

# %%
final = dict(reversed(sorted(stockset.items(), key=lambda item: item[1])))

# %%
print(final)
# Out:
# {'AAPL': 2358852976640, 'MSFT': 1800627290112, 'AMZN': 1004765446144, 'TSLA': 602972356608, 'WMT': 375623680000, 'PFE': 276399390720, 'DIS': 167912669184, 'SE': 25727598592, 'TME': 7543105536, 'TWST': 2141812992, 'QRTEB': 788782720, 'HUYA': 550206016, 'FDMT': 436973472, 'RBT': 418743008, 'TUSK': 378025280, 'POWW': 367257568, 'CWCO': 267752416, 'TRUE': 171820752, 'XL': 164297936, 'RVPH': 102010064, 'SRZN': 62869988, 'GRFX': 37710712, 'TFFP': 37707144, 'XGN': 34146840, 'BKYI': 13183544, 'VS': 4488278, 'LMAOU': 0}

# %%
#first 9 are high, next 9 mid, next 9 low market cap
