# %% [markdown]
# # New Code Review
#
# Goals
# * Analyze news api code

# %% [markdown]
# # Agranya's code

# %%
#pip install newsapi-python

# %%
import requests
from newsapi import NewsApiClient
import json
import pandas as pd
from datetime import datetime, timedelta

# %%
#newsapi_APIkey = '5d87fd57f2a3427ab10fd1f582c06748'
newsapi_APIkey = '647d0c7e3dff4bb2a550b7aa5db477c7'

newsapi_APIurl = 'https://newsapi.org/v2/everything?q=keyword&apiKey=' + newsapi_APIkey
response = requests.get(newsapi_APIurl)

print(response)
# Out:
# <Response [200]>

# %%
newsapi = NewsApiClient(api_key = newsapi_APIkey)

# %%
today = datetime.today().strftime('%Y-%m-%d')
change_days = (datetime.today()-timedelta(days=4)).strftime('%Y-%m-%d')
#print(today, change)

now = datetime.now().strftime('%Y-%m-%dT%H:%M:%S')
change_hrs = (datetime.now()-timedelta(hours=4)).strftime('%Y-%m-%dT%H:%M:%S')
print(now, change_hrs)
# Out:
# 2022-11-08T22:34:29 2022-11-08T18:34:29

# %%
ticker = 'snap'

newsapi = NewsApiClient(api_key = newsapi_APIkey)

# %%
top_headlines = newsapi.get_top_headlines(q = ticker, 
                                          category='business',
                                          country='us')

pretty_top_headlines = json.dumps(top_headlines, indent = 1)

all_articles = newsapi.get_everything(q=ticker,
                                      sources='bbc-news,the-verge',
                                      domains='bbc.co.uk,techcrunch.com',
                                      from_param=change_hrs,
                                      to=now,
                                      language='en')

pretty_all_articles = json.dumps(all_articles, indent = 1)

# %%
json_pth = json.loads(pretty_top_headlines)
print(json_pth["totalResults"])
# Out:
# 0

# %%
print(top_headlines)
# Out:
# {'status': 'ok', 'totalResults': 0, 'articles': []}

# %%
print(all_articles)
# Out:
# {'status': 'ok', 'totalResults': 1, 'articles': [{'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'Makena Kelly', 'title': 'The midterms turned politicians into content creators', 'description': 'Eight million members of Gen Z became eligible to vote in the midterm elections this year. Candidates like Josh Shapiro and John Fetterman are using popular platforms like BeReal and TikTok to get them out to vote.', 'url': 'https://www.theverge.com/2022/11/8/23447655/midterm-elections-tiktok-bereal-josh-shapiro-john-fetterman-tim-ryan', 'urlToImage': 'https://cdn.vox-cdn.com/thumbor/C2u8sEQ7VNM-SfMelh2T_-SOTVo=/0x0:3439x2293/1200x628/filters:focal(2247x1074:2248x1075)/cdn.vox-cdn.com/uploads/chorus_asset/file/24179059/1244531631.jpg', 'publishedAt': '2022-11-08T19:09:05Z', 'content': 'The midterms turned politicians into content creators\r\nThe midterms turned politicians into content creators\r\n / More than 8 million young people became eligible to vote this year. They want the same… [+7469 chars]'}]}

# %%
th_sources = 0
aa_sources = 0
tickers = ['msft', 'twtr', 'snap', 'hood', 'wmt', 'pton', 'wish', 'cprx', 'tsla', 'aapl']
for i in range(len(tickers)):
    curr_ticker = tickers[i]
    th = newsapi.get_top_headlines(q=curr_ticker, 
                                   category='business',
                                   country='us')
    pretty_th = json.dumps(th, indent = 1)
    aa = newsapi.get_everything(q=curr_ticker,
                                #sources='bbc-news,the-verge',
                                #domains='bbc.co.uk,techcrunch.com',
                                from_param=change_hrs,
                                to=now,
                                language='en')
    pretty_aa = json.dumps(aa, indent = 1)
    json_th = json.loads(pretty_th)
    json_aa = json.loads(pretty_aa)
    #print(curr_ticker, json_th["totalResults"], ",", json_aa["totalResults"])
    print(pretty_aa, "\n\n\nSPLIT\n\n\n")
    th_sources += json_th["totalResults"]
    aa_sources += json_aa["totalResults"]
print("Top headlines", th_sources)
print("Total articles", aa_sources)
# Out:
# {
#  "status": "ok",
#  "totalResults": 6,
#  "articles": [
#   {
#    "source": {
#     "id": "cnn",
#     "name": "CNN"
#    },
#    "author": "Brian Fung",
#    "title": "EU opens deeper probe of Microsoft's Activision deal",
#    "description": "The European Union is taking a closer look at Microsoft's proposed $68.7 billion purchase of video game giant Activision Blizzard, citing concerns the deal could hurt competition in the video game industry.",
#    "url": "https://www.cnn.com/2022/11/08/tech/eu-probe-microsoft-activision-ctrp/index.html",
#    "urlToImage": "https://media.cnn.com/api/v1/images/stellar/prod/221108130553-world-of-warcraft-gamers-event-germany-file-restricted.jpg?c=16x9&q=w_800,c_fill",
#    "publishedAt": "2022-11-08T19:19:48Z",
#    "content": "The European Union is taking a closer look at Microsofts proposed $68.7 billion purchase of video game giant Activision Blizzard, citing concerns the deal could hurt competition in the video game ind\u2026 [+1635 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "CNBC"
#    },
#    "author": "Kevin Stankiewicz",
#    "title": "Stocks usually climb in the year after midterms. These Club names have been big winners in prior cycles",
#    "description": "This exercise is designed to show how much stocks moved during these bullish periods not why they performed as they did.",
#    "url": "https://www.cnbc.com/2022/11/08/midterm-election-rallies-club-names-that-have-been-big-winners-before.html",
#    "urlToImage": "https://image.cnbcfm.com/api/v1/image/107087760-1657659984159-gettyimages-1241863963-AFP_32EB4CU.jpeg?v=1667944413&w=1920&h=1080",
#    "publishedAt": "2022-11-08T20:53:33Z",
#    "content": "Strange, but true: The S &amp; P 500 has been solidly higher 12 months after the midterm elections in every cycle since 1954, according to Yardeni Research, regardless of which party won or lost. The\u2026 [+5319 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Yahoo Entertainment"
#    },
#    "author": "Fahad Saleem",
#    "title": "15 Best Warren Buffett Stocks to Buy Now",
#    "description": "In this article, we discuss the 15 best stock picks of Warren Buffett. If you want to skip our detailed analysis of these stocks, go directly to the 5 Best...",
#    "url": "https://finance.yahoo.com/news/15-best-warren-buffett-stocks-190416152.html",
#    "urlToImage": "https://media.zenfs.com/en/insidermonkey.com/3b3772b94332fa7747824ebfe73f6744",
#    "publishedAt": "2022-11-08T19:04:16Z",
#    "content": "In this article, we discuss the 15 best stock picks of Warren Buffett. If you want to skip our detailed analysis of these stocks, go directly to the 5 Best Warren Buffett Stocks To Buy Now.\u00a0\r\nWarren \u2026 [+13695 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Seeking Alpha"
#    },
#    "author": "Caterer Goodman Partners",
#    "title": "Don't Buy Meta Platforms Until There Is Fundamental Change",
#    "description": "Meta Platforms revenue is declining primarily due to TikTok but also easing economy and growing ad sales from AMZN, MSFT and NFLX. Click here to read more.",
#    "url": "https://seekingalpha.com/article/4554954-dont-buy-meta-platforms-until-there-is-change",
#    "urlToImage": "https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1200715713/image_1200715713.jpg?io=getty-c-w750",
#    "publishedAt": "2022-11-08T21:23:25Z",
#    "content": "5./15 WEST\r\nIs Meta a value buy or value trap?\r\n Meta Platforms (NASDAQ:META) needs no introduction. What does need introducing is that Meta is no longer a growth stock. Meta has fallen more than 70%\u2026 [+20269 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "MarketWatch"
#    },
#    "author": "MarketWatch Automation",
#    "title": "Company Close Updates: Adobe Inc. stock rises Tuesday, outperforms market",
#    "description": "Shares of Adobe Inc. inched 0.88% higher to $302.17 Tuesday, on what proved to be an all-around positive trading session for the stock market, with the S&P...",
#    "url": "https://www.marketwatch.com/story/adobe-inc-stock-rises-tuesday-outperforms-market-01667943236-40e27e9b9f48",
#    "urlToImage": "https://images.mktw.net/im-220105/social",
#    "publishedAt": "2022-11-08T21:33:00Z",
#    "content": "Shares of Adobe Inc. \r\n ADBE,\r\n +0.88%\r\ninched 0.88% higher to $302.17 Tuesday, on what proved to be an all-around positive trading session for the stock market, with the S&amp;P 500 Index \r\n SPX,\r\n \u2026 [+800 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "MarketWatch"
#    },
#    "author": "Wallace Witkowski",
#    "title": "The Ratings Game: Take-Two stock sinks as analysts walk off mobile weakness, focus on pipeline",
#    "description": "Take-Two Interactive Software Inc.\u00a0shares fell double-digits Tuesday after Wall Street absorbed a hefty outlook cut owing to the videogame publisher's overestimate of the mobile market in the latter half of the year",
#    "url": "https://www.marketwatch.com/story/take-two-stock-sinks-as-analysts-walk-off-mobile-weakness-focus-on-pipeline-11667934039",
#    "urlToImage": "https://images.mktw.net/im-625784/social",
#    "publishedAt": "2022-11-08T19:00:00Z",
#    "content": "Take-Two Interactive Software Inc.\u00a0shares fell double-digits Tuesday after Wall Street absorbed a hefty outlook cut owing to the videogame publishers overestimate of the mobile market in the latter h\u2026 [+3104 chars]"
#   }
#  ]
# }
#
#
# SPLIT
#
#
#
# {
#  "status": "ok",
#  "totalResults": 2,
#  "articles": [
#   {
#    "source": {
#     "id": null,
#     "name": "Benzinga"
#    },
#    "author": "Adam Eckert",
#    "title": "EXCLUSIVE: Gene Munster Says Apple, Tesla Are Standouts Among Mega-Cap Tech \u2014 Why 'Optionality' Will Driv - Benzinga",
#    "description": "Big tech is out of favor amid current market conditions, but one analyst said\u00a0it's only a matter of time before investors regained an appetite for growth.",
#    "url": "https://www.benzinga.com/trading-ideas/long-ideas/22/11/29621137/exclusive-gene-munster-says-apple-tesla-are-standouts-among-mega-cap-tech-why-optionalit",
#    "urlToImage": "https://cdn.benzinga.com/files/images/story/2022/11/08/tslaaapl.png?width=1200&height=800&fit=crop",
#    "publishedAt": "2022-11-08T20:04:49Z",
#    "content": "Big tech is out of favor amid current market conditions, but one analyst said\u00a0it's only a matter of time before investors regained an appetite for growth.\u00a0\r\nWhat Happened:\u00a0Loup\u00a0Funds'\u00a0Gene Munster an\u2026 [+2788 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Seeking Alpha"
#    },
#    "author": "Valuentum",
#    "title": "Tesla Looks Cheap But Twitter May Be A Distraction",
#    "description": "Tesla has revolutionized the auto industry, in our view. Read why we think TSLA shares look cheap on the basis of its cash-based sources of intrinsic value.",
#    "url": "https://seekingalpha.com/article/4554992-tesla-looks-cheap-but-twitter-may-be-a-distraction",
#    "urlToImage": "https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1140204814/image_1140204814.jpg?io=getty-c-w750",
#    "publishedAt": "2022-11-08T22:27:07Z",
#    "content": "jetcityimage\r\nBy Valuentum Analysts\r\n Tesla, Inc. (NASDAQ:TSLA) is one of the most followed stocks out there, and CEO Elon Musk has reached celebrity status thanks to his huge following on Twitter (T\u2026 [+8792 chars]"
#   }
#  ]
# }
#
#
# SPLIT
#
#
#
# {
#  "status": "ok",
#  "totalResults": 79,
#  "articles": [
#   {
#    "source": {
#     "id": "business-insider",
#     "name": "Business Insider"
#    },
#    "author": "gkay@insider.com (Grace Kay)",
#    "title": "The 6 most interesting quotes from the podcast hosted by Elon Musk's friends that Twitter staff were reportedly told to listen to amid layoffs",
#    "description": "A Twitter VP told staff that the podcast would provide insight into why layoffs were necessary. The show issues a dire warning for the economy.",
#    "url": "https://www.businessinsider.com/all-in-podcast-hosts-elon-musk-twitter-layoffs-summary-2022-11",
#    "urlToImage": "https://i.insider.com/630e369eabd32c001809ffdf?width=1200&format=jpeg",
#    "publishedAt": "2022-11-08T21:37:14Z",
#    "content": "As Elon Musk cut Twitter's workforce roughly in half, some surviving employees were told to listen to a podcast hosted by two of the billionaire's closest associates, according to a report from Platf\u2026 [+7013 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "/FILM"
#    },
#    "author": "Ryan Scott",
#    "title": "What Non-Marvel Fans Need To Know To Watch Black Panther: Wakanda Forever",
#    "description": "One of the biggest movies of the year - if not the single biggest movie of the year - is nearly upon us in the form of \"Black Panther: Wakanda Forever.\" This is the sequel to 2018's \"Black Panther,\" which became a downright pop culture phenomenon upon its rel\u2026",
#    "url": "https://www.slashfilm.com/1091314/what-non-marvel-fans-need-to-know-to-watch-black-panther-wakanda-forever/",
#    "urlToImage": "https://www.slashfilm.com/img/gallery/what-non-marvel-fans-need-to-know-to-watch-black-panther-wakanda-forever/l-intro-1667924770.jpg",
#    "publishedAt": "2022-11-08T20:00:45Z",
#    "content": "While, in the end, these movies didn't end up messing with the central characters of \"Wakanda Forever\" all that much in terms of them being alive or dead, \"Avengers: Infinity War\" and \"Avengers: Endg\u2026 [+1500 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Eonline.com"
#    },
#    "author": "Gabrielle Chung",
#    "title": "Inside Bachelor Alum Madison Prewett's Honeymoon",
#    "description": "Marriage\u00a0has been nothing but rosy for\u00a0Madison Prewett.\nCase in point: The Bachelor Nation star's honeymoon with new husband Grant Troutt. As seen in photos posted by Madison on Nov. 7, the couple...",
#    "url": "https://www.eonline.com/news/1353793/bachelor-nations-madison-prewett-shares-glimpse-inside-honeymoon-with-husband-grant-troutt",
#    "urlToImage": "https://akns-images.eonline.com/eol_images/Entire_Site/2022917/rs_1200x1200-221017163723-1200-Madison-Prewett-Marries-Grant-Michael-Troutt.jpg?fit=around%7C1080:1080&output-quality=90&crop=1080:1080;center,top",
#    "publishedAt": "2022-11-08T21:41:51Z",
#    "content": "Marriage\u00a0has been nothing but rosy for\u00a0Madison Prewett.\r\nCase in point: The Bachelor Nation star's honeymoon with new husband Grant Troutt. As seen in photos posted by Madison on Nov. 7, the couple w\u2026 [+788 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "NBCSports.com"
#    },
#    "author": "ProFootball Talk on NBC Sports",
#    "title": "Steelers waive Ryan Anderson, sign Josh Malone from practice squad",
#    "description": "The Steelers waived linebacker Ryan Anderson from the 53-player roster, the team announced Tuesday. He played 28 defensive snaps in five games this season and had one tackle. Washington made Anderson a second-round choice in 2017, and he spent four seasons th\u2026",
#    "url": "https://profootballtalk.nbcsports.com/2022/11/08/steelers-waive-ryan-anderson-sign-josh-malone-from-practice-squad/?ocid=Yahoo&partner=ya5nbcs",
#    "urlToImage": "https://media.zenfs.com/en/profootballtalk.nbcsports.com/f91ae6914333875c589debe5794e8fab",
#    "publishedAt": "2022-11-08T21:29:01Z",
#    "content": "The Steelers waived linebacker Ryan Anderson from the 53-player roster, the team announced Tuesday.\r\nHe played 28 defensive snaps in five games this season and had one tackle.\r\nWashington made Anders\u2026 [+888 chars]"
#   },
#   {
#    "source": {
#     "id": "usa-today",
#     "name": "USA Today"
#    },
#    "author": "Giants Wire",
#    "title": "Julian Love will take over as Giants\u2019 defensive signal-caller",
#    "description": "With Xavier McKinney out a month (or more), Julian Love will take over as the New York Giants' defensive signal caller.",
#    "url": "https://giantswire.usatoday.com/2022/11/08/julian-love-will-take-over-new-york-giants-defensive-signal-caller/",
#    "urlToImage": "https://s.yimg.com/ny/api/res/1.2/Cg2ud0jKtxCsSGyLxF9F7w--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/new_york_giants_wire_usa_today_sports_articles_591/526051e08b1b2a873029de25630f3140",
#    "publishedAt": "2022-11-08T21:02:08Z",
#    "content": "With safety Xavier McKinney out for the next four weeks (and beyond) due to his unfortunate off-field injury, the New York Giants will have veteran Julian Love donning the green dot on his helmet and\u2026 [+1042 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "FiveThirtyEight"
#    },
#    "author": "Josh Planos, \nJosh Planos\nhttps://fivethirtyeight.com/contributors/josh-planos/",
#    "title": "Why Is The College Football World Sleeping On Ohio State?",
#    "description": "The college football season began visibly off script for Ohio State. On the first defensive snap of its first game against Notre Dame, the Buckeyes missed a tackle, allowed a 54-yard completion and earned a 15-yard penalty for roughing the passer. By the end \u2026",
#    "url": "https://fivethirtyeight.com/features/why-is-the-college-football-world-sleeping-on-ohio-state/",
#    "urlToImage": "https://fivethirtyeight.com/wp-content/uploads/2022/11/GettyImages-1435654262-16x9-1.jpg?w=712",
#    "publishedAt": "2022-11-08T20:00:05Z",
#    "content": "C.J. Stroud and the Ohio State Buckeyes are off to a hot start but wheres the hype?GAELEN MORSE / GETTY IMAGES\r\nThe college football season began visibly off script for Ohio State. On the first defen\u2026 [+7868 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Hootsuite.com"
#    },
#    "author": "Michelle Cyca",
#    "title": "What Is Cameo? Using Celebrity Videos to Promote Your Brand",
#    "description": "If you\u2019ve ever wanted George Costanza to roast your dad on Festivus or Chaka Khan to sing you happy birthday,\u2026\nThe post What Is Cameo? Using Celebrity Videos to Promote Your Brand appeared first on Social Media Marketing & Management Dashboard.",
#    "url": "https://blog.hootsuite.com/what-is-cameo/",
#    "urlToImage": "https://blog.hootsuite.com/wp-content/uploads/2022/11/what-is-cameo.png",
#    "publishedAt": "2022-11-08T20:00:56Z",
#    "content": "If youve ever wanted George Costanza to roast your dad on Festivus or Chaka Khan to sing you happy birthday, Cameo can make your dreams come true. You probably know Cameo as a platform that allows fa\u2026 [+11344 chars]"
#   },
#   {
#    "source": {
#     "id": "fox-sports",
#     "name": "Fox Sports"
#    },
#    "author": null,
#    "title": "NFL odds Week 10: How to bet Commanders-Eagles, pick",
#    "description": "Here's everything you need to know about Commanders-Eagles, from the point spread, moneyline, total Over/Under and expert pick from Jason McIntyre",
#    "url": "https://www.foxsports.com/stories/nfl/odds-week-10-how-to-bet-commanders-eagles-pick",
#    "urlToImage": "https://a57.foxsports.com/statics.foxsports.com/www.foxsports.com/content/uploads/2022/11/1408/814/H2B-NFL-horiz.jpg?ve=1&tl=1",
#    "publishedAt": "2022-11-08T21:29:45Z",
#    "content": "The Washington Commanders (4-5) will look to end two streaks by the Philadelphia Eagles (8-0) when the longtime NFC East Division rivals meet on Monday Night Football in the City of Brotherly Love.\r\n\u2026 [+1933 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Sports Illustrated"
#    },
#    "author": "Matt De Lima",
#    "title": "IDP Waiver Wire Report Week 10",
#    "description": "An injury gives Raiders linebacker Blake Martinez an opportunity to redeem his 2022 IDP season.",
#    "url": "https://www.si.com/fantasy/2022/11/08/idp-waiver-wire-report-week-10-blake-martinez-damar-hamlin",
#    "urlToImage": "https://www.si.com/.image/t_share/MTkzNjA3NDA5MTQ1NDg4ODgw/las-vegas-raiders-blake-martinez.jpg",
#    "publishedAt": "2022-11-08T19:02:26Z",
#    "content": "As we close in on the fantasy postseason, we need to try to gravitate toward 100% snap players and I prefer players from bad defenses among that set.\r\nA good defense forces three-and-outs. We don\u2019t l\u2026 [+7275 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "NBCSports.com"
#    },
#    "author": "NBC Sports Boston",
#    "title": "Did Patriots tip their plays vs. Colts? Bill Belichick gives surprising answer",
#    "description": "Did Shaquille Leonard and the Colts defense really know what plays the Patriots were running Sunday? Head coach Bill Belichick gave a surprisingly direct answer.",
#    "url": "https://www.nbcsports.com/boston/patriots/did-patriots-tip-their-plays-vs-colts-bill-belichick-gives-surprising-answer",
#    "urlToImage": "https://s.yimg.com/ny/api/res/1.2/J1Ju5uAuwfWDBN7OO8Q72A--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/csnne.com/94a01b83160c64a73c15d8960488e44b",
#    "publishedAt": "2022-11-08T18:50:00Z",
#    "content": "Belichick makes surprising admission about Patriots tipping plays originally appeared on NBC Sports Boston\r\nThe Bill Belichick-led New England Patriots pride themselves on out-scheming other teams an\u2026 [+2656 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "NBCSports.com"
#    },
#    "author": "ProFootball Talk on NBC Sports",
#    "title": "Raiders to release Johnathan Abram",
#    "description": "The Raiders are moving on from one of their former first-round picks. Las Vegas is releasing safety Johnathan Abram, according to multiple reports. Abram was the third of the three first-round picks the Raiders made in 2019, their last season in Oakland. Sele\u2026",
#    "url": "https://profootballtalk.nbcsports.com/2022/11/08/raiders-to-release-johnathan-abram/?ocid=Yahoo&partner=ya5nbcs",
#    "urlToImage": "https://media.zenfs.com/en/profootballtalk.nbcsports.com/ccb17c33eae8cfd540980f309d3edb70",
#    "publishedAt": "2022-11-08T20:25:08Z",
#    "content": "The Raiders are moving on from one of their former first-round picks.\r\nLas Vegas is releasing safety Johnathan Abram, according to multiple reports.\r\nAbram was the third of the three first-round pick\u2026 [+1070 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "The Guardian"
#    },
#    "author": "Amy Remeikis",
#    "title": "Australia politics live news: opinions divided on legacy of Liberal \u2018warrior\u2019 Peter Reith; Sri Lanka cricketers face investigation",
#    "description": "The Liberal \u2018stalwart\u2019 renowned for his role in the union-busting waterfront dispute dies; T20 squad face probe for alleged bad behaviour while in Australia. Follow live<ul><li>Get our morning and afternoon news emails, free app or daily news podcast</li></ul\u2026",
#    "url": "https://www.theguardian.com/australia-news/live/2022/nov/09/australia-live-news-peter-reith-sri-lanka-parliament-senate-estimates-defence-industrial-relations-workplace-laws-anthony-albanese-peter-dutton-environment-cop-peter-reith",
#    "urlToImage": "https://i.guim.co.uk/img/media/e694ae0f9caeaa3308fd06edb03b9c7bfd24e0c3/0_0_8256_4954/master/8256.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctbGl2ZS5wbmc&enable=upscale&s=6738a0686f34753c3e5ecfb72c5b7c76",
#    "publishedAt": "2022-11-08T20:23:43Z",
#    "content": "Key events(3)Australia(3)\r\nGood morning\r\nWelcome to the Wednesday parliament sitting, where estimates will continue to mean everyone inside the parliament is annoyed about something.\r\nIts been that s\u2026 [+5804 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "NBCSports.com"
#    },
#    "author": "NBC Sports Philadelphia",
#    "title": "Eagles sign Andre Chachere to roster, Fred Johnson to practice squad",
#    "description": "The Eagles on Tuesday finally signed special teamer Andre Chachere to their 53-man roster. By Dave Zangaro",
#    "url": "https://www.nbcsports.com/philadelphia/eagles/eagles-sign-andre-chachere-roster-fred-johnson-practice-squad",
#    "urlToImage": "https://s.yimg.com/ny/api/res/1.2/e8jY1ESD_6DxldtQSoTmyg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/csnphilly.com/243198ce3b5ec3083cae217ea60c34b3",
#    "publishedAt": "2022-11-08T18:49:13Z",
#    "content": "Eagles finally add special teams stud to 53-man roster originally appeared on NBC Sports Philadelphia\r\nThe Eagles on Tuesday signed defensive back and special teams ace Andre Chachere to their 53-man\u2026 [+1498 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Nbcsportsedge.com"
#    },
#    "author": "NBC Sports EDGE",
#    "title": "32 Fantasy Stats that Defined Week 9",
#    "description": "Kyle Dvorchak gives one fantasy football stat that defined every NFL team in Week 9. (Cary Edmondson-USA TODAY Sports)",
#    "url": "https://www.nbcsportsedge.com/article/numbers/32-fantasy-stats-defined-week-9?cid=Yahoo&partner=ya4nbcs",
#    "urlToImage": "https://s.yimg.com/ny/api/res/1.2/Nfg4lqD36pf2rtG5FjDFfw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzQ-/https://media.zenfs.com/en/rotoworld.com/dd4c537ab3cf0eef1140b7a5195f60dd",
#    "publishedAt": "2022-11-08T21:02:34Z",
#    "content": "Its NFL season and that means youve got a chance at $100,000 with Sunday Night 7. Predict what will happen on Sunday Night Football and watch along to see if youll be the next big winner. Click here \u2026 [+9924 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Daily Mail"
#    },
#    "author": "Sarah Sotoodeh",
#    "title": "Rihanna flashes her backside in racy sheer black lingerie while posing on a bed",
#    "description": "Her Savage X Fenty vol. 4 is set to stream on Amazon Prime Video on November 9.",
#    "url": "https://www.dailymail.co.uk/tvshowbiz/article-11404609/Rihanna-flashes-backside-racy-sheer-black-lingerie-posing-bed.html",
#    "urlToImage": "https://i.dailymail.co.uk/1s/2022/11/08/18/64323389-0-image-a-50_1667931992357.jpg",
#    "publishedAt": "2022-11-08T18:46:24Z",
#    "content": "Her Savage X Fenty vol. 4 is set to stream on Amazon Prime Video on November 9.\u00a0\r\nAnd one day before the show's release, Rihanna showcased her incredible post-baby body in a series of sizzling snaps \u2026 [+3761 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "NBCSports.com"
#    },
#    "author": "Charean Williams",
#    "title": "Xavier McKinney won\u2019t put timeline on return after surgery on multiple fingers",
#    "description": "Giants safety Xavier McKinney took \u201cfull responsibility\u201d for an ATV accident in Cabo that will sideline him for multiple weeks.\u201cIt was an unfortunate event,\u201d McKinney said, via SNY Giants. \u201cI got into a Can-Am [off-road vehicle] accident. It kind of just basi\u2026",
#    "url": "https://profootballtalk.nbcsports.com/2022/11/08/xavier-mckinney-wont-put-timeline-on-return-after-surgery-on-multiple-fingers/",
#    "urlToImage": "https://profootballtalk.nbcsports.com/wp-content/uploads/sites/25/2022/11/GettyImages-1436246077-e1667940454164.jpg",
#    "publishedAt": "2022-11-08T20:48:32Z",
#    "content": "Giants safety Xavier McKinney took full responsibility for an ATV accident in Cabo that will sideline him for multiple weeks.\r\nIt was an unfortunate event, McKinney said, via SNY Giants. I got into a\u2026 [+1662 chars]"
#   },
#   {
#    "source": {
#     "id": "usa-today",
#     "name": "USA Today"
#    },
#    "author": "Ducks Wire",
#    "title": "How Oregon Ducks performed during NFL Week 9 action",
#    "description": "The Marcus Mariota vs. Justin Herbert matchup was underwhelming, but there were still plenty of great Duck performances in NFL's Week 9.",
#    "url": "https://duckswire.usatoday.com/lists/how-oregon-ducks-performed-during-nfl-week-9-action/",
#    "urlToImage": "https://s.yimg.com/ny/api/res/1.2/TRMEU1cXr.I.2rKccPODkg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/ducks_wire_usa_today_articles_200/08c95df02f93a26b3b62ad7ba20cace5",
#    "publishedAt": "2022-11-08T18:48:34Z",
#    "content": "Oregon Ducks fans had an opportunity to see two of the greatest quarterbacks in school history, Marcus Mariota and Justin Herbert, go against each other on Sunday when the Atlanta Falcons took on the\u2026 [+3424 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Daily Mail"
#    },
#    "author": "Bethan Edwards",
#    "title": "Rochelle Humes wows in an extreme plunging gown as she attends Glamour Women of the Year Awards 2022",
#    "description": "The TV presenter, 33, made sure all eyes were on her as she posed in an extreme plunging black gown at the Glamour Women of the Year Awards 2022 in London on Tuesday.",
#    "url": "https://www.dailymail.co.uk/tvshowbiz/article-11404903/Rochelle-Humes-wows-extreme-plunging-gown-attends-Glamour-Women-Year-Awards-2022.html",
#    "urlToImage": "https://i.dailymail.co.uk/1s/2022/11/08/20/64327373-0-image-a-90_1667939454232.jpg",
#    "publishedAt": "2022-11-08T20:48:00Z",
#    "content": "Rochelle Humes made sure all eyes were on her as she posed in an extreme plunging black gown at the Glamour Women of the Year Awards 2022 in London on Tuesday.\u00a0\r\nThe TV presenter, 33, dressed to impr\u2026 [+2900 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "NBCSports.com"
#    },
#    "author": "NBC Sports BayArea",
#    "title": "Steph Curry, Steve Kerr confident Jordan Poole will get out of 'funk'",
#    "description": "Jordan Poole is in a little bit of a \"funk\" right now with the Warriors, but his coach and teammates aren't too worried.",
#    "url": "https://www.nbcsports.com/bayarea/warriors/steph-curry-steve-kerr-confident-jordan-poole-will-get-out-funk",
#    "urlToImage": "https://s.yimg.com/ny/api/res/1.2/bPpyGbR0PjNAYYuTHrraiQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/csnbayarea.com/a7a7e5764860951e25ec43dc2639877b",
#    "publishedAt": "2022-11-08T22:16:48Z",
#    "content": "Steph, Kerr confident JP will snap out of early-season 'funk' originally appeared on NBC Sports Bayarea\r\nComing off a breakout season in his third year in the NBA, Jordan Poole made a splash in the l\u2026 [+2559 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Forbes"
#    },
#    "author": "Diane Brady, Forbes Staff, \n Diane Brady, Forbes Staff\n https://www.forbes.com/sites/dianebrady/",
#    "title": "CxO: Insights On The Midterms, Marketing And Musk\u2019s Terrible Week",
#    "description": "Musk would not be the first leader to discover that different industries require different strengths. Plenty of other business rock stars stumbled when they moved on to new gigs.",
#    "url": "https://www.forbes.com/sites/dianebrady/2022/11/08/cxo-insights-on-the-midterms-marketing-and-musks-terrible-week/",
#    "urlToImage": "https://imageio.forbes.com/specials-images/imageserve/636a9e1e688c6b872142ae4f/0x0.jpg?format=jpg&width=1200",
#    "publishedAt": "2022-11-08T18:36:38Z",
#    "content": "Debating the future of marketing with (L to R) Ashley Haynes-Gaspar of Microsoft, Kickstarter CEO Everette Taylor, Square CMO Lauren Weinberg, and Sherry Phillips, Chief Sales &amp; Marketing Officer\u2026 [+6463 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Daily Mail"
#    },
#    "author": "Milly Veitch",
#    "title": "Gogglebox star Tom Malone Jr pays tribute to his girlfriend's father after he passes away",
#    "description": "The Gogglebox star, 26, who quit the fan-favourite show last year, and his partner Bryony Briscoe have been left devastated after Peter Briscoe died on Tuesday.",
#    "url": "https://www.dailymail.co.uk/tvshowbiz/article-11405025/Gogglebox-star-Tom-Malone-Jr-pays-tribute-girlfriends-father-passes-away.html",
#    "urlToImage": "https://i.dailymail.co.uk/1s/2022/11/08/21/64329035-0-image-a-137_1667943026734.jpg",
#    "publishedAt": "2022-11-08T21:53:47Z",
#    "content": "Tom Malone Jr has revealed that his girlfriend's father has passed away, with a touching tribute on Instagram.\r\nThe Gogglebox star, 26, who quit the show last year, and his partner Bryony Briscoe hav\u2026 [+2341 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Yahoo Entertainment"
#    },
#    "author": "Yahoo Sports",
#    "title": "Daily Fantasy Football Week 10: Lineup building blocks and undervalued options to target",
#    "description": "Fantasy football analyst Dalton Del Don lays out the DFS landscape for Week 10.",
#    "url": "https://sports.yahoo.com/daily-fantasy-football-week-10-lineup-building-blocks-and-undervalued-options-to-target-193448819.html",
#    "urlToImage": "https://s.yimg.com/ny/api/res/1.2/LfGSu31eFyt30u3XDuc0xA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2022-11/f5f0bea0-5f93-11ed-95fa-f987bb20cc88",
#    "publishedAt": "2022-11-08T19:34:48Z",
#    "content": "Whether you've played Daily Fantasy on Yahoo before or are giving it a try for the first time, this weekly column will take an early look at the DFS landscape, revealing whom I like building lineups \u2026 [+5304 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "CBS Sports"
#    },
#    "author": "Heath Cummings",
#    "title": "Fantasy Football Week 10 Running Back Preview: Waiver adds, projections, DFS plays, and more",
#    "description": "Everything you need to know about the running back position in Week 10",
#    "url": "https://www.cbssports.com/fantasy/football/news/fantasy-football-week-10-running-back-preview-waiver-adds-projections-dfs-plays-and-more/",
#    "urlToImage": "https://sportshub.cbsistatic.com/i/r/2022/11/08/3aa58249-3342-46c2-82a8-1fa1daf23b6d/thumbnail/1200x675/cf55a9ef4d5fa74462ad74345cd9be06/dandre-swift-1400-us.jpg",
#    "publishedAt": "2022-11-08T21:35:31Z",
#    "content": "We've become comfortable with the idea of running back committees by now. But even in a league full of committees, the Lion's situation has become unique.\u00a0 \r\nFor one thing, D'Andre Swift has had a te\u2026 [+2491 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Complex"
#    },
#    "author": "Sanj Patel",
#    "title": "Stone Island Celebrates 40th Anniversary With Special Edition Luminescent Jacket",
#    "description": "Following the release of its Heritage Camo collection, Stone Island now returns to drop its third commemorative capsule in celebration of its 40th\u00a0anniversary.",
#    "url": "https://www.complex.com/style/stone-island-lumienscent-jacket",
#    "urlToImage": "https://images.complex.com/complex/images/c_fill,f_auto,g_center,w_1200/fl_lossy,pg_1/uhd77lupqlpopnsovqrp/stone-island-jacket-40th-anniversary-luminescent-special-edition-2",
#    "publishedAt": "2022-11-08T19:01:05Z",
#    "content": "Following the release of its Heritage Camo collection, Stone Island now returns to drop its third commemorative capsule in celebration of its 40th\u00a0anniversary.\u00a0\r\nA hooded jacket made of a two-compone\u2026 [+707 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Gizmodo Australia"
#    },
#    "author": "Zachariah Kelly",
#    "title": "Where Are All the Smart Glasses We Were Promised?",
#    "description": "Where are all the life-changing augmented reality projects that we expected to see over the past 10 years?\nThe post Where Are All the Smart Glasses We Were Promised? appeared first on Gizmodo Australia.\n\n\u00a0\u00a0Related Stories\r\n<ul><li>Is It Worth Getting an Apple\u2026",
#    "url": "https://www.gizmodo.com.au/2022/11/smart-glasses-australia/",
#    "urlToImage": "https://www.gizmodo.com.au/wp-content/uploads/sites/2/2022/11/08/smart-glasses.png?quality=80&resize=1280,720",
#    "publishedAt": "2022-11-08T22:22:26Z",
#    "content": "Every now and again I\u2019m reminded of \u2018Google Glass\u2019, Google\u2019s attempt at spearheading the augmented reality market by pushing a videogame-like heads-up display at a consumer level. For many, it was th\u2026 [+4006 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Kansas City Star"
#    },
#    "author": "Kansas City Star",
#    "title": "Why Andy Reid interrupted Travis Kelce\u2019s post-game interview after Chiefs beat Titans",
#    "description": "There was a particular meaning behind Andy Reid\u2019s interaction with Travis Kelce. This is it.",
#    "url": "https://www.kansascity.com/sports/spt-columns-blogs/sam-mcdowell/article268453577.html",
#    "urlToImage": "https://media.zenfs.com/en/kansas_city_star_mcclatchy_articles_677/c4f141351f18617c284a6dcd2e1dfb4a",
#    "publishedAt": "2022-11-08T20:04:32Z",
#    "content": "Travis Kelce stood in front of his locker late Sunday, holding court in front of a group of local reporters. He had just begun his answer to the first question when a booming voice interrupted.\r\nThe \u2026 [+4246 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "The Mac Observer"
#    },
#    "author": "Jeff Butts",
#    "title": "Apple Seeds iOS 16.2 Beta 2 With 5G in India, Medication Widget, More",
#    "description": "As widely expected, Apple released a new build of iOS 16.2 to developers Tuesday. With this latest iOS 16.2 beta, Apple is adding support for 5G networks in India. Along the way, the iPhone maker has fixed a pesky Lock Screen bug that\u2019s been driving many of u\u2026",
#    "url": "https://www.macobserver.com/news/apple-seeds-ios-162-beta-2-with-5g-in-india-medication-widget-more/",
#    "urlToImage": "https://www.macobserver.com/wp-content/uploads/2022/11/iOS-16.2-beta-2.jpg",
#    "publishedAt": "2022-11-08T19:59:50Z",
#    "content": "As widely expected, Apple released a new build of iOS 16.2 to developers Tuesday. With this latest iOS 16.2 beta, Apple is adding support for 5G networks in India. Along the way, the iPhone maker has\u2026 [+2968 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Theeverygirl.com"
#    },
#    "author": "katherine",
#    "title": "7 All-Natural Ways to Up Your Libido That You Haven\u2019t Tried Yet",
#    "description": "Let\u2019s face it: We can\u2019t expect to always have a sex drive in high gear, and it takes more than\nThe post 7 All-Natural Ways to Up Your Libido That You Haven\u2019t Tried Yet appeared first on The Everygirl.",
#    "url": "http://theeverygirl.com/natural-ways-increase-libido/",
#    "urlToImage": "https://media.theeverygirl.com/wp-content/uploads/2022/10/all-natural-libido-the-everygirl-social.png",
#    "publishedAt": "2022-11-08T21:01:35Z",
#    "content": "The Everygirls product selections are curated by the editorial team. If you buy something through our links, we may earn an affiliate commission at no cost to you. We only recommend products we genui\u2026 [+7781 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "The Boston Globe"
#    },
#    "author": "Janelle Nanos",
#    "title": "One year into its pilot, Camp Harbor View\u2019s guaranteed income program is working",
#    "description": "Recipients of the monthly, no-strings-attached $583 are making ends meet, paying down debt, and perhaps most significantly, reporting less stress and better overall mental health.",
#    "url": "https://www.bostonglobe.com/2022/11/08/business/one-year-into-its-pilot-camp-harbor-views-guaranteed-income-program-is-working/",
#    "urlToImage": "https://bostonglobe-prod.cdn.arcpublishing.com/resizer/DCl_wgp3lyuY2BBK8rvWJFvSrW8=/506x0/cloudfront-us-east-1.images.arcpublishing.com/bostonglobe/AH6I5NGUGCVH3J7EFEQH26XNTY.JPG",
#    "publishedAt": "2022-11-08T18:48:32Z",
#    "content": "One of the unanticipated, and really exciting, benefits of this initiative has been seeing the positive impact it has had on the mental well-being and social and emotional well-being of these familie\u2026 [+4766 chars]"
#   },
#   {
#    "source": {
#     "id": "business-insider",
#     "name": "Business Insider"
#    },
#    "author": "gkay@insider.com (Grace Kay)",
#    "title": "Tech investor says Elon Musk's decision to 'cut deep' in Twitter layoffs could set a new standard for Silicon Valley",
#    "description": "David Friedberg said companies could quickly realize: \"Wow, you don't actually need 50% of the workforce in order to keep the product running.\"",
#    "url": "https://www.businessinsider.com/tech-investor-david-friedberg-elon-musk-twitter-layoffs-set-standard-2022-11",
#    "urlToImage": "https://i.insider.com/636a8a0c113fe10018350579?width=1200&format=jpeg",
#    "publishedAt": "2022-11-08T19:29:16Z",
#    "content": "Some of Elon Musk's closest associates are celebrating his decision to lay off about 50% of Twitter's staff.\r\nTech investor David Friedberg said Musk's cost-cutting measures at Twitter could quickly \u2026 [+2674 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Slate Magazine"
#    },
#    "author": "Shirin Ali",
#    "title": "Why It Will Take So Long to Get Results Tonight",
#    "description": "What to expect from various states when it comes to results.",
#    "url": "https://slate.com/news-and-politics/2022/11/poll-closing-times-ballot-start-count-states.html",
#    "urlToImage": "https://compote.slate.com/images/edf9293a-ed4e-4213-b97d-296ce19274eb.jpeg?crop=5392%2C3595%2Cx0%2Cy0&width=1560",
#    "publishedAt": "2022-11-08T21:49:48Z",
#    "content": "Its here! Today is the day we are voting. Yes, some might have already gone in-person to early vote, and others have done absentee ballots, but the rest, the fly-by-the-seat-of-your-pants voters, wil\u2026 [+9619 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Hollywood Life"
#    },
#    "author": "Michaela Leung",
#    "title": "Save 50% On Burberry Sunglasses In This Early Black Friday Sale",
#    "description": "Save big on designer digs as an early Black Friday treat.",
#    "url": "https://hollywoodlife.com/shop/burberry-sunglasses-deal-4888441/",
#    "urlToImage": "https://hollywoodlife.com/wp-content/uploads/2022/11/thick-black-sunglasses-adobe-ftr.jpg",
#    "publishedAt": "2022-11-08T22:00:11Z",
#    "content": "Image Credit: sofiko14 / adobe stock\r\nIf you purchase an independently reviewed product or service through a link on our website, we may receive an affiliate commission.\r\nMoreShopping\r\nNow that Hallo\u2026 [+1799 chars]"
#   },
#   {
#    "source": {
#     "id": "the-washington-post",
#     "name": "The Washington Post"
#    },
#    "author": "Ian Livingston",
#    "title": "PM Update: Sweater weather continues through Wednesday",
#    "description": "Seasonably chilly tonight. Overall, it's feeling a lot more like November than it did to start the month.",
#    "url": "https://www.washingtonpost.com/weather/2022/11/08/dc-area-forecast-seasonable-temperatures/",
#    "urlToImage": "https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/YNFIAORJ6BG4FACSGMYZNSNXRI.jpg&w=1440",
#    "publishedAt": "2022-11-08T22:05:10Z",
#    "content": "Comment on this story\r\nTodays average high in Washington is 61. So, the afternoon high of 62 was much more in line with what we should expect compared to the recent warm spell. Tonights temperatures \u2026 [+1327 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Footballoutsiders.com"
#    },
#    "author": "Cale Clinton",
#    "title": "Bills Upset Makes Jets Legitimate Playoff Contenders",
#    "description": "Bills Upset Makes Jets Legitimate Playoff Contenders\nCale Clinton\n08 Nov 2022, 04:45pm\n\n \n \n The New York Jets' 20-17 win over the Buffalo Bills proved that, despite what a certain ex-Carolina Panthers head coach would lead you to believe via the life story o\u2026",
#    "url": "https://www.footballoutsiders.com/any-given-sunday/2022/bills-upset-makes-jets-legitimate-playoff-contenders",
#    "urlToImage": "https://www.footballoutsiders.com/files/coverphotos/JohnsonJer22.jpg",
#    "publishedAt": "2022-11-08T21:45:59Z",
#    "content": "NFL Week 9 - The New York Jets' 20-17 win over the Buffalo Bills proved that, despite what a certain ex-Carolina Panthers head coach would lead you to believe via the life story of Jay-Z, it doesn't \u2026 [+13202 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Askubuntu.com"
#    },
#    "author": "raj",
#    "title": "CUPS moved to snap recently?",
#    "description": "I'm running Ubuntu 20.04. I just noticed after issuing snap list command that my list of installed snaps includes cups, version 2.4.2-4. Directory /snap/cups was updated a few days ago:\ndrwxr-xr-x 11 root root 159 Oct 22 07:21 836\nlrwxrwxrwx 1 root root 3 Nov\u2026",
#    "url": "https://askubuntu.com/questions/1439775/cups-moved-to-snap-recently",
#    "urlToImage": "https://cdn.sstatic.net/Sites/askubuntu/Img/apple-touch-icon@2.png?v=c492c9229955",
#    "publishedAt": "2022-11-08T20:00:00Z",
#    "content": "I'm running Ubuntu 20.04. I just noticed after issuing snap list command that my list of installed snaps includes cups, version 2.4.2-4. Directory /snap/cups was updated a few days ago:\r\ndrwxr-xr-x 1\u2026 [+2032 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Werd.com"
#    },
#    "author": "Andrew Peloquin",
#    "title": "35 Perfect Stocking Stuffer Ideas for Men in 2022",
#    "description": "Sadly, it can feel like stocking stuffers for men are thrown together as an afterthought. You know what I\u2019m talking about: dollar store headphones, a backup power cable, colorful socks, a necktie...boring.",
#    "url": "https://www.werd.com/stocking-stuffers-for-men/",
#    "urlToImage": "https://www.werd.com/wp-content/uploads/2022/11/stocking-stuffers-for-men.jpg",
#    "publishedAt": "2022-11-08T21:55:29Z",
#    "content": "By Staff Writers\u00a0 | \u00a0Updated November 8, 2022\r\nSadly, it can feel like stocking stuffers for men are thrown together as an afterthought. You know what Im talking about: dollar store headphones, a bac\u2026 [+21505 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Askubuntu.com"
#    },
#    "author": "Wingarmac",
#    "title": "problems on Snap software vs apt software",
#    "description": "I have been using Ubuntu since 18.04. Before, I most often used Windows.\nI've used the Synaptics software center longside the gnome one for GUI installation at the beginning. Then I've learned to use apt with the gnome-terminal and got used to it.\nFor a while\u2026",
#    "url": "https://askubuntu.com/questions/1439791/problems-on-snap-software-vs-apt-software",
#    "urlToImage": "https://cdn.sstatic.net/Sites/askubuntu/Img/apple-touch-icon@2.png?v=c492c9229955",
#    "publishedAt": "2022-11-08T22:04:17Z",
#    "content": "I have been using Ubuntu since 18.04. Before, I most often used Windows.\r\nI've used the Synaptics software center longside the gnome one for GUI installation at the beginning. Then I've learned to us\u2026 [+1641 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Daily Mail"
#    },
#    "author": "Lillian Gissen",
#    "title": "Melania Trump votes alongside Donald in first public outing since AUGUST",
#    "description": "The former First Lady, 52, stepped out for a rare appearance on Tuesday, as she and her husband, former President Donald, 76, went to vote in the midterm elections.",
#    "url": "https://www.dailymail.co.uk/femail/article-11404367/Melania-Trump-votes-alongside-Donald-public-outing-AUGUST.html",
#    "urlToImage": "https://i.dailymail.co.uk/1s/2022/11/08/18/64323483-0-image-a-486_1667932088792.jpg",
#    "publishedAt": "2022-11-08T18:37:49Z",
#    "content": "Melania Trump broke cover as she stepped out to vote alongside her husband, former President Donald Trump, on Tuesday - in her first public appearance since August.\r\nMelania, 52, who has stayed large\u2026 [+7414 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Boston Herald"
#    },
#    "author": "Tribune News Service",
#    "title": "Dolphins Q&A: Can struggling defense be fixed? Plus, Emmanuel Ogbah, Jason Sanders questions",
#    "description": "Here\u2019 s the latest installment of our Miami Dolphins Q&A, where South Florida Sun Sentinel writers David Furones and Chris Perkins answer questions from readers. It\u2019 s also encouraging that the Dolphins are still winning despite giving up 27 points to the Det\u2026",
#    "url": "https://www.bostonherald.com/2022/11/08/dolphins-qa-can-struggling-defense-be-fixed-plus-emmanuel-ogbah-jason-sanders-questions/",
#    "urlToImage": "https://www.bostonherald.com/wp-content/uploads/2022/11/202211081423TMS_____MNGTRPUB_SPORTS-DOLPHINS-QA-CAN-STRUGGLING-DEFENSE-BE-1-FL5.jpg?w=1024&h=683",
#    "publishedAt": "2022-11-08T19:30:17Z",
#    "content": "Here\u2019s the latest installment of our Miami Dolphins Q&amp;A, where South Florida Sun Sentinel writers David Furones and Chris Perkins answer questions from readers.\r\nQ: When does the dominant D begin\u2026 [+5982 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "NBCSports.com"
#    },
#    "author": "Myles Simmons",
#    "title": "Raiders to release Johnathan Abram",
#    "description": "The Raiders are moving on from one of their former first-round picks.Las Vegas is releasing safety Johnathan Abram, according to multiple reports.Abram was the third of the three first-round picks the Raiders made in 2019, their last season in Oakland. Select\u2026",
#    "url": "https://profootballtalk.nbcsports.com/2022/11/08/raiders-to-release-johnathan-abram/",
#    "urlToImage": "https://profootballtalk.nbcsports.com/wp-content/uploads/sites/25/2022/11/GettyImages-1428233853-e1667939099370.jpg",
#    "publishedAt": "2022-11-08T20:25:34Z",
#    "content": "The Raiders are moving on from one of their former first-round picks.\r\nLas Vegas is releasing safety Johnathan Abram, according to multiple reports.\r\nAbram was the third of the three first-round pick\u2026 [+994 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "City A.M."
#    },
#    "author": "Leah Montebello",
#    "title": "FTX plunges following Binance bailout",
#    "description": "FTX coin plunged as much as 75 per cent this evening after crypto exchange Binance struck a dramatic deal to snap up its beleaguered rival. FTX, led by billionaire chief Sam Bankman-Fried, had been locked in a high-profile spat with Binance boss Changpeng Zha\u2026",
#    "url": "https://www.cityam.com/ftx-plunges-following-binance-bailout/",
#    "urlToImage": "https://www.cityam.com/wp-content/uploads/2022/11/CZ-SBF-e1667823730211.jpg",
#    "publishedAt": "2022-11-08T21:20:39Z",
#    "content": "Tuesday 08 November 2022 9:20 pm\r\nPhoto via Twitter\r\nFTX coin plunged as much as 75 per cent this evening after crypto exchange Binance struck a dramatic deal to snap up its beleaguered rival.\r\nFTX, \u2026 [+780 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "tor.com"
#    },
#    "author": "Tracy Deonn",
#    "title": "Read an Excerpt From Bloodmarked",
#    "description": "Book Two of The Legendborn Cycle: The shadows have risen, and the line is law.",
#    "url": "https://www.tor.com/2022/11/08/excerpts-bloodmarked-by-tracy-deonn/",
#    "urlToImage": "https://i0.wp.com/www.tor.com/wp-content/uploads/2022/11/Bloodmarked-header.png?fit=1200%2C+9999&crop=0%2C0%2C100%2C660px&quality=100&ssl=1",
#    "publishedAt": "2022-11-08T19:00:03Z",
#    "content": "The shadows have risen, and the line is law.\r\nWe\u2019re thrilled to share an excerpt from Bloodmarked, the second book in the Legendborn Cycle by Tracy Deonn, out from Simon &amp; Schuster Books for Youn\u2026 [+14405 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Footballoutsiders.com"
#    },
#    "author": "Ian O'Connor",
#    "title": "Waiver Wire Week 10: Jeff Wilson Jr. Tops the List",
#    "description": "Waiver Wire Week 10: Jeff Wilson Jr. Tops the List\nIan O'Connor\n08 Nov 2022, 02:44pm\n\n \n \n Waiver wire options typically aren't pretty, but they're often necessary. One player leads the pack this week as the top priority. Others are quality fill-ins, some of \u2026",
#    "url": "https://www.footballoutsiders.com/win-wire/2022/waiver-wire-week-10-jeff-wilson-jr-tops-list",
#    "urlToImage": "https://www.footballoutsiders.com/files/coverphotos/USATSI_19375509.jpg",
#    "publishedAt": "2022-11-08T19:44:58Z",
#    "content": "NFL Week 10 - Waiver wire options typically aren't pretty, but they're often necessary. One player leads the pack this week as the top priority. Others are quality fill-ins, some of which may become \u2026 [+8183 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Gizmodo Australia"
#    },
#    "author": "Cheryl Eddy",
#    "title": "Chuck Wendig\u2019s Wayward Is Almost Here, and Gizmodo Has Another Sneak Peek",
# ...
#    "urlToImage": "https://cdn.benzinga.com/files/images/story/2022/11/08/tslaaapl.png?width=1200&height=800&fit=crop",
#    "publishedAt": "2022-11-08T20:04:49Z",
#    "content": "Big tech is out of favor amid current market conditions, but one analyst said\u00a0it's only a matter of time before investors regained an appetite for growth.\u00a0\r\nWhat Happened:\u00a0Loup\u00a0Funds'\u00a0Gene Munster an\u2026 [+2788 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Seeking Alpha"
#    },
#    "author": "Joshua Fineman",
#    "title": "Tesla may have downside to $165 or potentially $109/share, technical strategist says",
#    "description": "Fundstrat technical strategist Mark Newton believes that electric vehicle maker Tesla (TSLA) may have a lot more downside from current levels and potentially could hit as low...",
#    "url": "https://seekingalpha.com/news/3904045-tesla-may-have-downside-to-165-or-potentially-109share-technical-strategist-says",
#    "urlToImage": "https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1140204814/image_1140204814.jpg?io=getty-c-w750",
#    "publishedAt": "2022-11-08T21:48:35Z",
#    "content": "By clicking Accept All Cookies, you agree to the storing of cookies on your device to enhance site navigation, analyze site usage, and assist in our marketing efforts. Cookie Policy"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "International Business Times"
#    },
#    "author": "Manan Bhavnani",
#    "title": "Elon Musk's Wealth Plunges By Nearly Half In 2022, Down From $340B Peak",
#    "description": "The Tesla and Twitter CEO's wealth has taken a nosedive this year, particularly since his purchase of the social media platform.",
#    "url": "https://www.ibtimes.com/elon-musks-wealth-plunges-nearly-half-2022-down-340b-peak-3633460",
#    "urlToImage": "https://d.ibtimes.com/en/full/3837233/spacex-owner-tesla-ceo-elon-musk-speaks-during-conversation-legendary-game-designer-todd-howard.jpg",
#    "publishedAt": "2022-11-08T19:50:40Z",
#    "content": "While Elon Musk remains the world's richest person, his net wealth has been cut nearly in half from its $340 billion peak a year ago.\r\nThe chief of executive of Tesla (TSLA) and Twitter is worth abou\u2026 [+1024 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Seeking Alpha"
#    },
#    "author": "Valuentum",
#    "title": "Tesla Looks Cheap But Twitter May Be A Distraction",
#    "description": "Tesla has revolutionized the auto industry, in our view. Read why we think TSLA shares look cheap on the basis of its cash-based sources of intrinsic value.",
#    "url": "https://seekingalpha.com/article/4554992-tesla-looks-cheap-but-twitter-may-be-a-distraction",
#    "urlToImage": "https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1140204814/image_1140204814.jpg?io=getty-c-w750",
#    "publishedAt": "2022-11-08T22:27:07Z",
#    "content": "jetcityimage\r\nBy Valuentum Analysts\r\n Tesla, Inc. (NASDAQ:TSLA) is one of the most followed stocks out there, and CEO Elon Musk has reached celebrity status thanks to his huge following on Twitter (T\u2026 [+8792 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Seeking Alpha"
#    },
#    "author": "Wright's Research",
#    "title": "Li Auto: Our Pick As A Competitor In China's Booming EV Market",
#    "description": "Li Auto has a strong position in China's booming EV market. Read why I think LI may be the best choice as a competitor to BYD and TSLA in the EV car market.",
#    "url": "https://seekingalpha.com/article/4554916-li-auto-our-pick-as-a-competitor-in-chinas-booming-ev-market",
#    "urlToImage": "https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1355626508/image_1355626508.jpg?io=getty-c-w750",
#    "publishedAt": "2022-11-08T20:08:52Z",
#    "content": "leonello/iStock via Getty Images\r\nLi Auto Inc. (NASDAQ:LI) is one of the leaders in China's new electric vehicle (\"EV\") market. Their stock has suffered a loss of more than 45% over the past 3 months\u2026 [+14123 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Investor's Business Daily"
#    },
#    "author": "Investor's Business Daily",
#    "title": "Dow Jones Up On Election Day; These 'GOP Stocks' Gain As Donald Trump SPAC Falls; Bitcoin Dives On This - Investor's Business Daily",
#    "description": "<ol><li>Dow Jones Up On Election Day; These 'GOP Stocks' Gain As Donald Trump SPAC Falls; Bitcoin Dives On This\u00a0\u00a0Investor's Business Daily\r\n</li><li>LIVE: Watch stocks trade in real time as investors anticipate midterm election results \u2060\u2014 11/8/2022\u00a0\u00a0CNBC Tele\u2026",
#    "url": "https://www.investors.com/market-trend/stock-market-today/dow-jones-surges-on-election-day-these-republican-stocks-gain-bitcoin-coin-dive-on-this-movedonald-trump-stock-dwac/",
#    "urlToImage": "https://www.investors.com/wp-content/uploads/2021/10/Stock-redtrump-03-shutt.jpg",
#    "publishedAt": "2022-11-08T21:18:00Z",
#    "content": "The Dow Jones Industrial Average moved higher as Americans voted on Election Day. A number of so-called \"Republican stocks\" made gains, though the Donald Trump SPAC Digital World Acquisition (DWAC) f\u2026 [+6323 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Investopedia"
#    },
#    "author": "Igor Greenwald",
#    "title": "Nio Facing Growth Slowdown Amid China Zero-COVID Curbs",
#    "description": "The Chinese EV maker's Q3 loss to be reported Nov. 10 is seen widening as production problems, economic malaise threaten to stunt sales growth.",
#    "url": "https://www.investopedia.com/nio-q3-fy2022-earnings-6826674",
#    "urlToImage": "https://www.investopedia.com/thmb/t0wPnO7jXZkI0GyvAcsI8DRk-k0=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/INV_Nio_3Q22_ErnsPreview_GettyImages-1232435354-5ff56850571042f28cedf3219bd06627.jpg",
#    "publishedAt": "2022-11-08T21:36:13Z",
#    "content": "<ul><li>Chinese electric vehicles maker Nio is expected to post a deeper Q3 loss early on Nov. 10.</li><li>October vehicle deliveries were down from September despite the launch of European sales and\u2026 [+4247 chars]"
#   }
#  ]
# }
#
#
# SPLIT
#
#
#
# {
#  "status": "ok",
#  "totalResults": 11,
#  "articles": [
#   {
#    "source": {
#     "id": null,
#     "name": "Benzinga"
#    },
#    "author": "Adam Eckert",
#    "title": "EXCLUSIVE: Gene Munster Says Apple, Tesla Are Standouts Among Mega-Cap Tech \u2014 Why 'Optionality' Will Driv - Benzinga",
#    "description": "Big tech is out of favor amid current market conditions, but one analyst said\u00a0it's only a matter of time before investors regained an appetite for growth.",
#    "url": "https://www.benzinga.com/trading-ideas/long-ideas/22/11/29621137/exclusive-gene-munster-says-apple-tesla-are-standouts-among-mega-cap-tech-why-optionalit",
#    "urlToImage": "https://cdn.benzinga.com/files/images/story/2022/11/08/tslaaapl.png?width=1200&height=800&fit=crop",
#    "publishedAt": "2022-11-08T20:04:49Z",
#    "content": "Big tech is out of favor amid current market conditions, but one analyst said\u00a0it's only a matter of time before investors regained an appetite for growth.\u00a0\r\nWhat Happened:\u00a0Loup\u00a0Funds'\u00a0Gene Munster an\u2026 [+2788 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "CNBC"
#    },
#    "author": "Kevin Stankiewicz",
#    "title": "Stocks usually climb in the year after midterms. These Club names have been big winners in prior cycles",
#    "description": "This exercise is designed to show how much stocks moved during these bullish periods not why they performed as they did.",
#    "url": "https://www.cnbc.com/2022/11/08/midterm-election-rallies-club-names-that-have-been-big-winners-before.html",
#    "urlToImage": "https://image.cnbcfm.com/api/v1/image/107087760-1657659984159-gettyimages-1241863963-AFP_32EB4CU.jpeg?v=1667944413&w=1920&h=1080",
#    "publishedAt": "2022-11-08T20:53:33Z",
#    "content": "Strange, but true: The S &amp; P 500 has been solidly higher 12 months after the midterm elections in every cycle since 1954, according to Yardeni Research, regardless of which party won or lost. The\u2026 [+5319 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "MarketWatch"
#    },
#    "author": "Jon Swartz, , Jeremy C. Owens",
#    "title": "Disney stock down 6% after earnings, revenue miss estimates",
#    "description": "Disney finishes fiscal year with biggest sales total in history and strongest sales growth since 1996, but better-than-expected streaming growth in fourth quarter can't overcome disappointing sales and profit",
#    "url": "https://www.marketwatch.com/story/disney-posts-wide-earnings-and-sales-miss-to-wrap-up-record-year-stock-falls-6-11667942471",
#    "urlToImage": "https://images.mktw.net/im-604180/social",
#    "publishedAt": "2022-11-08T21:22:48Z",
#    "content": "Walt Disney Co. wrapped up its fiscal year with record sales and its best revenue growth in more than 25 years, but a miss on earnings and revenue for the fourth quarter hurt the stock late Tuesday.D\u2026 [+4100 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "MarketWatch"
#    },
#    "author": "MarketWatch Automation",
#    "title": "Company Close Updates: Autodesk Inc. stock rises Tuesday, outperforms market",
#    "description": "Shares of Autodesk Inc. advanced 2.12% to $199.01 Tuesday, on what proved to be an all-around positive trading session for the stock market, with the S&P 500...",
#    "url": "https://www.marketwatch.com/story/autodesk-inc-stock-rises-tuesday-outperforms-market-01667943242-196272e48a08",
#    "urlToImage": "https://images.mktw.net/im-220105/social",
#    "publishedAt": "2022-11-08T21:34:00Z",
#    "content": "Shares of Autodesk Inc. \r\n ADSK,\r\n +2.12%\r\nadvanced 2.12% to $199.01 Tuesday, on what proved to be an all-around positive trading session for the stock market, with the S&amp;P 500 Index \r\n SPX,\r\n +0\u2026 [+797 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "MarketWatch"
#    },
#    "author": "Jon Swartz",
#    "title": "Netflix is interested in carrying live sports: report",
#    "description": "Netflix Inc. is thinking of getting into the game of offering live sports, much as its rivals Walt Disney Co. , Apple Inc. , Amazon.com Inc. and Comcast Corp. do, according to a Wall Street Journal report Tuesday. The video-streaming company, which spends bil\u2026",
#    "url": "https://www.marketwatch.com/story/netflix-is-interested-in-carrying-live-sports-report-2022-11-08",
#    "urlToImage": "https://s.wsj.net/public/resources/MWimages/MW-GP644_MicroS_ZG_20180906154215.jpg",
#    "publishedAt": "2022-11-08T18:54:52Z",
#    "content": "Netflix Inc. \r\n NFLX,\r\n +1.31%\r\nis thinking of getting into the game of offering live sports, much as its rivals Walt Disney Co. \r\n DIS,\r\n -1.36%\r\n,\r\n Apple Inc. \r\n AAPL,\r\n -0.29%\r\n,\r\n Amazon.com Inc\u2026 [+794 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "MarketWatch"
#    },
#    "author": "MarketWatch Automation",
#    "title": "Company Close Updates: Xerox Holdings Corp. stock falls Tuesday, underperforms market",
#    "description": "Shares of Xerox Holdings Corp. slipped 1.09% to $14.58 Tuesday, on what proved to be an all-around great trading session for the stock market, with the S&P...",
#    "url": "https://www.marketwatch.com/story/xerox-holdings-corp-stock-falls-tuesday-underperforms-market-01667946815-09bac08fe81f",
#    "urlToImage": "https://images.mktw.net/im-220105/social",
#    "publishedAt": "2022-11-08T22:33:00Z",
#    "content": "Shares of Xerox Holdings Corp. \r\n XRX,\r\n -1.09%\r\nslipped 1.09% to $14.58 Tuesday, on what proved to be an all-around great trading session for the stock market, with the S&amp;P 500 Index \r\n SPX,\r\n +\u2026 [+785 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Barron's"
#    },
#    "author": "Angela Palumbo",
#    "title": "Block Faces Competition With Apple. Why This Analyst Says It's Now a Buy.",
#    "description": "Macquarie analyst Paul Golding upgraded shares of the payments company to Outperform from Neutral.",
#    "url": "https://www.barrons.com/articles/block-stock-bnpl-upgrade-51667932670",
#    "urlToImage": "https://images.barrons.com/im-656943/social",
#    "publishedAt": "2022-11-08T18:38:00Z",
#    "content": "There are concerns over how \r\n Block\r\n will perform compared with major competitors. One analyst, however, argues that the stock is worth buying following the payments companys latest quarterly resul\u2026 [+2661 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "MarketWatch"
#    },
#    "author": "Therese Poletti",
#    "title": "As Netflix and Disney move into ads, will Roku look to sell?",
#    "description": "The streaming company's disappointing fourth-quarter forecast has some on Wall Street questioning its future in the competitive streaming world, as ad purchasing slows and the company continues to spend.",
#    "url": "https://www.marketwatch.com/story/as-netflix-and-disney-move-into-ads-will-roku-look-to-sell-11667938619",
#    "urlToImage": "https://images.mktw.net/im-660489/social",
#    "publishedAt": "2022-11-08T20:17:00Z",
#    "content": "The streaming companys disappointing holiday forecast, coming ahead of new, cheaper ad-supported streaming packages from Netflix Inc. \r\n NFLX,\r\n +2.01%\r\nand Walt Disney Co. \r\n DIS,\r\n -0.64%\r\n,\r\n has \u2026 [+7296 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "MarketWatch"
#    },
#    "author": "Rachel Koning Beals",
#    "title": ": Apple, Pepsi and more big stock names are newest members of group buying \u2018greener\u2019 concrete and steel",
#    "description": "Pepsi,\u00a0Apple\u00a0and\u00a0Rio Tinto are among the newest members of an alliance committing $12 billion to buying near-zero-carbon concrete, steel, aluminum and more.",
#    "url": "https://www.marketwatch.com/story/apple-pepsi-and-more-big-stock-names-are-newest-members-of-group-buying-greener-concrete-and-steel-11667937785",
#    "urlToImage": "https://images.mktw.net/im-661418/social",
#    "publishedAt": "2022-11-08T20:03:00Z",
#    "content": "PepsiCo Inc.,\u00a0Apple Inc.\u00a0and\u00a0Rio Tinto PLC\u00a0can be counted among the newest members of a corporate alliance committing $12 billion to purchasing near-zero-carbon steel, aluminum, cement and other prod\u2026 [+4427 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "MarketWatch"
#    },
#    "author": "Michael Brush",
#    "title": "Quality and high dividends set these five semiconductor stocks apart from poorer-performing competitors",
#    "description": "The industry is in a down cycle, making select stocks attractive buying opportunities.",
#    "url": "https://www.marketwatch.com/story/quality-and-high-dividends-set-these-five-semiconductor-stocks-apart-from-poorer-performing-competitors-11667941676",
#    "urlToImage": "https://images.mktw.net/im-408638/social",
#    "publishedAt": "2022-11-08T21:07:00Z",
#    "content": "Its been a tough year in the stock market, but reserve some empathy for semiconductor investors. The iShares Semiconductor ETF \r\n SOXX,\r\n +2.20%\r\nis down 40.5% this year, compared with 19.6% for the \u2026 [+10344 chars]"
#   },
#   {
#    "source": {
#     "id": null,
#     "name": "Seeking Alpha"
#    },
#    "author": "Caterer Goodman Partners",
#    "title": "Don't Buy Meta Platforms Until There Is Fundamental Change",
#    "description": "Meta Platforms revenue is declining primarily due to TikTok but also easing economy and growing ad sales from AMZN, MSFT and NFLX. Click here to read more.",
#    "url": "https://seekingalpha.com/article/4554954-dont-buy-meta-platforms-until-there-is-change",
#    "urlToImage": "https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1200715713/image_1200715713.jpg?io=getty-c-w750",
#    "publishedAt": "2022-11-08T21:23:25Z",
#    "content": "5./15 WEST\r\nIs Meta a value buy or value trap?\r\n Meta Platforms (NASDAQ:META) needs no introduction. What does need introducing is that Meta is no longer a growth stock. Meta has fallen more than 70%\u2026 [+20269 chars]"
#   }
#  ]
# }
#
#
# SPLIT
#
#
#
# Top headlines 2
# Total articles 303

# %% [markdown]
# # Wisdm Code

# %%
th_sources = 0
aa_sources = 0
tickers = ['msft', 'twtr', 'snap', 'hood', 'wmt', 'pton', 'wish', 'cprx', 'tsla', 'aapl']

# %%
ticker = 'tsla'
top_headlines = newsapi.get_top_headlines(q=ticker, 
                                   category='business',
                                   country='us')

# %%
top_headlines['totalResults']
# Out:
# 1

# %%
pd.json_normalize(top_headlines['articles'])
# Out:
#   author                                              title  \
# 0   None  Musk sells Tesla shares worth $3.95 bln days a...
#
#                                          description  \
# 0  Tesla Inc <a href="https://www.reuters.com/com...
#
#                                                  url  \
# 0  https://www.reuters.com/business/autos-transpo...
#
#                                           urlToImage           publishedAt  \
# 0  https://www.reuters.com/resizer/p_lj8m9G343pN9...  2022-11-09T02:52:00Z
#
#                                              content source.id source.name
# 0  Nov 8 (Reuters) - Tesla Inc (TSLA.O) Chief Exe...   reuters     Reuters

# %%
aa = newsapi.get_everything(q=curr_ticker,
                                #sources='bbc-news,the-verge',
                                #domains='bbc.co.uk,techcrunch.com',
                                from_param=change_hrs,
                                to=now,
                                language='en')

# %%
aa['totalResults']
# Out:
# 11

# %%
pd.json_normalize(aa['articles']).head()
# Out:
#                           author  \
# 0                    Adam Eckert
# 1              Kevin Stankiewicz
# 2  Jon Swartz, , Jeremy C. Owens
# 3         MarketWatch Automation
# 4                     Jon Swartz
#
#                                                title  \
# 0  EXCLUSIVE: Gene Munster Says Apple, Tesla Are ...
# 1  Stocks usually climb in the year after midterm...
# 2  Disney stock down 6% after earnings, revenue m...
# 3  Company Close Updates: Autodesk Inc. stock ris...
# 4  Netflix is interested in carrying live sports:...
#
#                                          description  \
# 0  Big tech is out of favor amid current market c...
# 1  This exercise is designed to show how much sto...
# 2  Disney finishes fiscal year with biggest sales...
# 3  Shares of Autodesk Inc. advanced 2.12% to $199...
# 4  Netflix Inc. is thinking of getting into the g...
#
#                                                  url  \
# 0  https://www.benzinga.com/trading-ideas/long-id...
# 1  https://www.cnbc.com/2022/11/08/midterm-electi...
# 2  https://www.marketwatch.com/story/disney-posts...
# 3  https://www.marketwatch.com/story/autodesk-inc...
# 4  https://www.marketwatch.com/story/netflix-is-i...
#
#                                           urlToImage           publishedAt  \
# 0  https://cdn.benzinga.com/files/images/story/20...  2022-11-08T20:04:49Z
# 1  https://image.cnbcfm.com/api/v1/image/10708776...  2022-11-08T20:53:33Z
# 2           https://images.mktw.net/im-604180/social  2022-11-08T21:22:48Z
# 3           https://images.mktw.net/im-220105/social  2022-11-08T21:34:00Z
# 4  https://s.wsj.net/public/resources/MWimages/MW...  2022-11-08T18:54:52Z
#
#                                              content source.id  source.name
# 0  Big tech is out of favor amid current market c...      None     Benzinga
# 1  Strange, but true: The S &amp; P 500 has been ...      None         CNBC
# 2  Walt Disney Co. wrapped up its fiscal year wit...      None  MarketWatch
# 3  Shares of Autodesk Inc. \r\n ADSK,\r\n +2.12%\...      None  MarketWatch
# 4  Netflix Inc. \r\n NFLX,\r\n +1.31%\r\nis think...      None  MarketWatch
